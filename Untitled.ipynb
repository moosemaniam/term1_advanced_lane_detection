# %%
import pickle
import cv2
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import copy
from math import sqrt

# %matplotlib inline

#Load camera coefficients
cam_coef_pickle = pickle.load( open( "camera_cal/cam_coefs_pickle.p", "rb" ) )
mtx=cam_coef_pickle["mtx"]
dist=cam_coef_pickle["dist"]

# %%
enable_sanity_checks=False
plt_index=1
flag=1
left_fitx_last_good=None
right_fitx_last_good=None
ploty_last_good=None
left_curverad_last_good=None
right_curverad_last_good=None
offcenter_last_good=None
left_fit_last_good=None
right_fit_last_good=None
frame_no=0
enable_plot=1

def similarity(x,y):
    """ http://dataaspirant.com/2015/04/11/five-most-popular-similarity-measures-implementation-in-python/
    Euclidean distance"""
    return sqrt(sum(pow(a-b,2) for a, b in zip(x, y)))
    

def calculate_y(curve,x):
    """Calculate y pixel coordinate value, given curve and x pixel coordinate"""
    return ( curve[0]*x**2+curve[1]*x + curve[0])

def bad_curves_check(curve_latest,curve_last_good):
    """Checks if a given curve is too different from
    a last known good curve and returns true if so"""
    threshold=100.0
    val = similarity(curve_latest,curve_last_good)
    if(val > threshold):
        return True
    
    return False
    
    
    print("diff",a_diff,b_diff,c_diff)
    if(a_diff > threshold or b_diff > threshold or c_diff > threshold):
        print("Too much of a change")
        return True
    
    return False
    

def plot_image(img,string):
    global plt_index
    global enable_plot
    if(enable_plot!=1):
        return
    plt.subplot(11, 2, plt_index)
    plt.title(string)
    plt.imshow(img,cmap='gray')
    plt.axis('off')
    plt_index +=1
    
def windowed_lane_finder(img):
    global left_fitx_last_good
    global right_fitx_last_good
    global ploty_last_good
    global left_curverad_last_good
    global right_curverad_last_good
    global offcenter_last_good
    global left_fit_last_good
    global right_fit_last_good
    global flag
    global enable_sanity_checks
    
    binary_warped = img
    histogram = np.sum(binary_warped[binary_warped.shape[0]/2:,:], axis=0)
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    midpoint = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint
    
    # Choose the number of sliding windows
    nwindows = 9
    # Set height of windows
    window_height = np.int(binary_warped.shape[0]/nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50
    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []
    
    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Draw the windows on the visualization image
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),(0,255,0), 2) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),(0,255,0), 2) 
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xright_low) & (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))
        # Concatenate the arrays of indices
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)

    
    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 

    #if the pixel positions come up empty, then just send back the 
    #last good line found
    if(enable_sanity_checks == True and (len(leftx) == 0 or len(lefty)==0 or len(rightx)==0 or len(righty)==0)):    
        return left_fitx_last_good,right_fitx_last_good,ploty_last_good,left_curverad_last_good,right_curverad_last_good,offcenter_last_good
    
    #If we found lines, continue
    # Fit a second order polynomial to each
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)
    
    #No sanity check initially
    if(flag==1):
        flag=0
        left_fit_last_good = copy.deepcopy(left_fit)
        right_fit_last_good = copy.deepcopy(right_fit)
        
    #Check for sanity
    if(enable_sanity_checks == True and (bad_curves_check(left_fit,left_fit_last_good) or bad_curves_check(right_fit,right_fit_last_good)) ):
        return left_fitx_last_good,right_fitx_last_good,ploty_last_good,left_curverad_last_good,right_curverad_last_good,offcenter_last_good
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

    
    #Figure out the curve
    # Define conversions in x and y from pixels space to meters
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension

    y_eval = np.max(lefty)
    # Fit new polynomials to x,y in world space
   
    left_fit_cr = np.polyfit(lefty*ym_per_pix, leftx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(righty*ym_per_pix, rightx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    # Now our radius of curvature is in meters
    
    #Find the deviation of the car
    """1) Figure out x co-ordinates of laneright and lane left near the car
    2) Mid point of these x co-ordinates is the middle of the road
    3) xsize/2 of the image gives the x cordinates of the car
    4) Diff between values 2) and 3) gives the deviation of the car off center
    """
    left_index_x = np.argmax(lefty)
    left_x_coordinate = leftx[left_index_x]
    
    right_index_x = np.argmax(righty)
    right_x_coordinate = rightx[right_index_x]
    
    center_x_coordinate = (img.shape[1]/2)
    
    middle_of_lane_x_co_ordinate = right_x_coordinate - left_x_coordinate
    
    #Convert to meters
    offcenter = np.abs(xm_per_pix * (middle_of_lane_x_co_ordinate - center_x_coordinate))
    
    left_fit_last_good = copy.deepcopy(left_fit)
    right_fit_last_good = copy.deepcopy(right_fit)
    left_fitx_last_good = copy.deepcopy(left_fitx)
    right_fitx_last_good=copy.deepcopy(right_fitx)
    ploty_last_good=copy.deepcopy(ploty)
    left_curverad_last_good=copy.deepcopy(left_curverad)
    right_curverad_last_good=copy.deepcopy(right_curverad)
    offcenter_last_good=copy.deepcopy(offcenter)
    
    return left_fitx,right_fitx,ploty,left_curverad,right_curverad,offcenter

def abs_sobel_thresh(gray, orient='x', thresh=(0,255)):
    thresh_min = thresh[0]
    thresh_max = thresh[1]
    # Apply x or y gradient with the OpenCV Sobel() function
    # and take the absolute value
    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 1, 0))
    if orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 0, 1))
    # Rescale back to 8 bit integer
    scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
    # Create a copy and apply the threshold
    binary_output = np.zeros_like(scaled_sobel)
    # Here I'm using inclusive (>=, <=) thresholds, but exclusive is ok too
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    # Return the result
    return binary_output
def mag_thresh(gray, sobel_kernel=3, mag_thresh=(0, 255)):
    # Convert to grayscale
    # Take both Sobel x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Calculate the gradient magnitude
    gradmag = np.sqrt(sobelx**2 + sobely**2)
    # Rescale to 8 bit
    scale_factor = np.max(gradmag)/255 
    gradmag = (gradmag/scale_factor).astype(np.uint8) 
    # Create a binary image of ones where threshold is met, zeros otherwise
    binary_output = np.zeros_like(gradmag)
    binary_output[(gradmag >= mag_thresh[0]) & (gradmag <= mag_thresh[1])] = 1
    # Return the binary image
    return binary_output

def dir_threshold(gray, sobel_kernel=3, thresh=(-np.pi/4, np.pi/4)):
    # 2) Take the gradient in x and y separately
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # 3) Take the absolute value of the x and y gradients
    abs_sobelx = np.absolute(sobelx)
    abs_sobely = np.absolute(sobely)
    # 4) Use np.arctan2(abs_sobely, abs_sobelx) to calculate the direction of the gradient 
    absgraddir = np.arctan2(abs_sobely,abs_sobelx)
    # 5) Create a binary mask where direction thresholds are met
    binary_output =  np.zeros_like(absgraddir)
    binary_output[(absgraddir >= thresh[0]) & (absgraddir <= thresh[1])] = 1
    # 6) Return this mask as your binary_output 
    return binary_output

def apply_thresholding(img):
    ksize=9
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    S = hls[:,:,2]
    thresh = (130, 255)
    S_binary = np.zeros_like(S)
    S_binary[(S > thresh[0]) & (S <= thresh[1])] = 1
    
    R = img[:,:,0]
    thresh = (180, 255)
    R_binary = np.zeros_like(R)
    R_binary[(R > thresh[0]) & (R <= thresh[1])] = 1
    
   
    image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gradx = abs_sobel_thresh(image, orient='x',thresh=(40, 100))
    
    grady = abs_sobel_thresh(image, orient='y',thresh=(40, 100))
     
    mag_binary = mag_thresh(image, sobel_kernel=ksize, mag_thresh=(30, 100))
    dir_binary = dir_threshold(image, sobel_kernel=ksize, thresh=(1.1, 1.3))
   
    combined = np.zeros_like(dir_binary)
    #combined[S_binary==1 |(gradx == 1)  | ((mag_binary == 1) & (dir_binary == 1))] = 1
    combined[ (R_binary==1) | ((S_binary==1) & (grady == 1)) | (((gradx == 1) | (grady == 1)) & ((mag_binary == 1) & (dir_binary == 1)))] = 1
    #combined[(((gradx == 1) & (grady == 1)) | ((mag_binary == 1) | (dir_binary == 1)))] = 1
    plot_image(gradx,"gradx threshold")
    plot_image(grady,"grady threshold")
    plot_image(dir_binary,"Dir threshold")
    plot_image(mag_binary,"mag threshold")
    plot_image(S_binary,"S color threshold")
    plot_image(R_binary,"R color threshold")

    plot_image(combined,"Fully thresholded")
    return combined

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def corners_unwarp(img,mtx, dist,corners):
    gray=img
    # Search for corners in the grayscaled image
    img_size = (gray.shape[1], gray.shape[0])
        # For source points I'm grabbing the outer four detected corners
    src = corners
        # For destination points, I'm arbitrarily choosing some points to be
        # a nice fit for displaying our warped result 
        # again, not exact, but close enough for our purposes
    dst = np.array([[(398,633),(398,183),(933,183),(933,634)]], dtype=np.float32)
        # Given src and dst points, calculate the perspective transform matrix
    M = cv2.getPerspectiveTransform(src, dst)
    # Warp the image using OpenCV warpPerspective()
    warped = cv2.warpPerspective(undist, M, img_size)
    # Return the resulting image and matrix
    return warped, M

def find_lane_lines(img):
    imgshape = img.shape
    ysize = imgshape[0]
    xsize = imgshape[1]
    global frame_no
    dst = cv2.undistort(img, mtx, dist, None, mtx)
       
    image_int = apply_thresholding(dst)
    #return image_int
    vertices = np.array([[(50,ysize),(xsize/2 - 0.01*xsize, ysize/4+0.35*ysize), (xsize/2 + 0.02*xsize ,ysize/4+0.35*ysize), (xsize-10,ysize)]], dtype=np.int32)
    thresholded_image= region_of_interest(image_int,vertices)
    vertices = np.array([[(359,619),(532,495), (760,495), (960,619)]], dtype=np.float32)
    img_unwarped, M = corners_unwarp(thresholded_image,mtx,dist,vertices)
    plot_image(img_unwarped,"input to lane finder")
    left_fitx,right_fitx,ploty,left_curverad,right_curverad,offcenter = windowed_lane_finder(img_unwarped)
    print(left_curverad, 'm', right_curverad, 'm')
    
    warp_zero = np.zeros_like(img_unwarped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))
    
    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))
    
    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))
    Minv = np.linalg.pinv(M)
    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, Minv, (xsize, ysize)) 
    # Combine the result with the original image
    result = cv2.addWeighted(dst, 1, newwarp, 0.3, 0)

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(result,'Left radius of curvature  = %.2f m'%(left_curverad),(60,50), font, 1,(255,255,0),2,cv2.LINE_AA)
    cv2.putText(result,'Right radius of curvature = %.2f m'%(right_curverad),(60,80), font, 1,(255,255,0),2,cv2.LINE_AA)
    cv2.putText(result,'Off center by  %.2f m'%(offcenter),(60,110), font, 1,(255,255,0),2,cv2.LINE_AA)
    

    return result

# %%
#Try undistorting a test image
window_width = 50 
window_height = 80 # Break image into 9 vertical layers since image height is 720
margin = 100 # How much to slide left and right for searching

images = glob.glob('video_images/videofile845.jpg')

plt.figure(figsize=(12, 100))

for idx, fname in enumerate(images):
    print(fname)
    img = cv2.imread(fname)
    plot_image(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),fname)
    
    lanes = find_lane_lines(img) 
    plot_image(lanes,"Lanes")
# Out:
# video_images/videofile845.jpg
# /Users/vikasmk/miniconda2/envs/carnd-term1/lib/python3.5/site-packages/ipykernel/__main__.py:68: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2090.00678786 m 1950.42809002 m

# %%
#Lets now see how the video works
# Import everything needed to edit/save/watch video clips
enable_sanity_checks=True
enable_plot=False
from moviepy.editor import VideoFileClip
from IPython.display import HTML
output = 'advanced_lane_lines.mp4'
clip1 = VideoFileClip("project_video.mp4")
clip = clip1.fl_image(find_lane_lines) #NOTE: this function expects color images!!
# %time clip.write_videofile(output, audio=False)
# Out:
# 4124.16989044 m 1026.8005178 m
# [MoviePy] >>>> Building video advanced_lane_lines.mp4
# [MoviePy] Writing video advanced_lane_lines.mp4
#   0%|          | 1/1261 [00:00<09:59,  2.10it/s]
# 4124.16989044 m 1026.8005178 m
#   0%|          | 2/1261 [00:00<09:55,  2.11it/s]
# 2605.28730291 m 1801.57623626 m
#   0%|          | 3/1261 [00:01<09:50,  2.13it/s]
# 2897.88821463 m 2221.20478205 m
#   0%|          | 4/1261 [00:01<09:56,  2.11it/s]
# 2267.51814891 m 2181.45376444 m
#   0%|          | 5/1261 [00:02<09:53,  2.12it/s]
# 1894.32140396 m 5216.19963096 m
#   0%|          | 6/1261 [00:02<09:45,  2.15it/s]
# 2234.09649894 m 4845.70566413 m
#   1%|          | 7/1261 [00:03<09:37,  2.17it/s]
# 2123.54354804 m 4631.80508326 m
#   1%|          | 8/1261 [00:03<09:31,  2.19it/s]
# 2430.20498303 m 945.445632351 m
#   1%|          | 9/1261 [00:04<09:27,  2.21it/s]
# 2615.22988568 m 1161.46365433 m
#   1%|          | 10/1261 [00:04<09:18,  2.24it/s]
# 2489.94321356 m 2522.71611704 m
#   1%|          | 11/1261 [00:05<09:15,  2.25it/s]
# 2495.16951161 m 2323.81265381 m
#   1%|          | 12/1261 [00:05<09:26,  2.20it/s]
# 2667.62309119 m 2276.98851682 m
#   1%|          | 13/1261 [00:05<09:22,  2.22it/s]
# 3305.32668948 m 1856.4230569 m
#   1%|          | 14/1261 [00:06<09:23,  2.21it/s]
# 3286.46413952 m 1135.95696667 m
#   1%|          | 15/1261 [00:06<09:26,  2.20it/s]
# 2764.24465557 m 2065.39643621 m
#   1%|▏         | 16/1261 [00:07<09:31,  2.18it/s]
# 1944.91251805 m 3703.85042486 m
#   1%|▏         | 17/1261 [00:07<09:26,  2.20it/s]
# 1723.03475171 m 9991.53216486 m
#   1%|▏         | 18/1261 [00:08<09:14,  2.24it/s]
# 1964.84286083 m 19983.3562963 m
#   2%|▏         | 19/1261 [00:08<09:14,  2.24it/s]
# 2642.50288807 m 12314.1034367 m
#   2%|▏         | 20/1261 [00:09<09:22,  2.20it/s]
# 3430.64158692 m 7177.9407922 m
#   2%|▏         | 21/1261 [00:09<09:10,  2.25it/s]
# 3030.39020733 m 1348.15951085 m
#   2%|▏         | 22/1261 [00:09<09:03,  2.28it/s]
# 6711.25769861 m 2431.46581732 m
#   2%|▏         | 23/1261 [00:10<09:04,  2.27it/s]
# 12561.4159271 m 7714.84958931 m
#   2%|▏         | 24/1261 [00:10<09:02,  2.28it/s]
# 7408.98829025 m 8406.08085023 m
#   2%|▏         | 25/1261 [00:11<08:59,  2.29it/s]
# 7880.74010245 m 3002.15403646 m
#   2%|▏         | 26/1261 [00:11<08:47,  2.34it/s]
# 18474.8132227 m 2330.70731184 m
#   2%|▏         | 27/1261 [00:12<08:34,  2.40it/s]
# 71740.8333141 m 1035.04459552 m
#   2%|▏         | 28/1261 [00:12<08:24,  2.44it/s]
# 13748.9355235 m 1540.90429499 m
#   2%|▏         | 29/1261 [00:12<08:15,  2.48it/s]
# 3933.92039339 m 2041.7335986 m
#   2%|▏         | 30/1261 [00:13<08:33,  2.40it/s]
# 3207.02550152 m 1879.09672527 m
#   2%|▏         | 31/1261 [00:13<08:44,  2.34it/s]
# 3167.56240806 m 4342.70545597 m
#   3%|▎         | 32/1261 [00:14<08:59,  2.28it/s]
# 2638.27766988 m 4479.05704904 m
#   3%|▎         | 33/1261 [00:14<08:51,  2.31it/s]
# 1965.38769649 m 5412.40486892 m
#   3%|▎         | 34/1261 [00:15<08:56,  2.29it/s]
# 2204.13500771 m 1812.93900021 m
#   3%|▎         | 35/1261 [00:15<08:54,  2.29it/s]
# 2508.91563446 m 2961.10216082 m
#   3%|▎         | 36/1261 [00:15<08:56,  2.28it/s]
# 2423.46463373 m 6536.50644368 m
#   3%|▎         | 37/1261 [00:16<08:50,  2.31it/s]
# 2274.09735812 m 5609.52439602 m
#   3%|▎         | 38/1261 [00:16<08:33,  2.38it/s]
# 2843.54421397 m 922.795796636 m
#   3%|▎         | 39/1261 [00:17<08:19,  2.44it/s]
# 2333.89196462 m 1356.33356558 m
#   3%|▎         | 40/1261 [00:17<08:11,  2.49it/s]
# 2168.38903469 m 1425.82393312 m
#   3%|▎         | 41/1261 [00:17<08:10,  2.49it/s]
# 2036.15880427 m 1790.22215806 m
#   3%|▎         | 42/1261 [00:18<08:06,  2.50it/s]
# 1996.92193326 m 2413.76130821 m
#   3%|▎         | 43/1261 [00:18<08:30,  2.39it/s]
# 1691.55805218 m 4239.37687164 m
#   3%|▎         | 44/1261 [00:19<08:40,  2.34it/s]
# 1788.3530823 m 5466.87406659 m
#   4%|▎         | 45/1261 [00:19<08:46,  2.31it/s]
# 1867.75188579 m 5347.15611913 m
#   4%|▎         | 46/1261 [00:20<08:39,  2.34it/s]
# 1668.73017079 m 1742.15378621 m
#   4%|▎         | 47/1261 [00:20<08:32,  2.37it/s]
# 1704.72808665 m 1117.93132482 m
#   4%|▍         | 48/1261 [00:20<08:24,  2.41it/s]
# 1700.10185478 m 3409.31119431 m
#   4%|▍         | 49/1261 [00:21<08:21,  2.42it/s]
# 1626.19628086 m 2248.34624717 m
#   4%|▍         | 50/1261 [00:21<08:17,  2.43it/s]
# 1659.22383927 m 8349.23267206 m
#   4%|▍         | 51/1261 [00:22<08:16,  2.44it/s]
# 1718.92422662 m 881.705838658 m
#   4%|▍         | 52/1261 [00:22<08:15,  2.44it/s]
# 2217.25825492 m 943.166734999 m
#   4%|▍         | 53/1261 [00:22<08:12,  2.45it/s]
# 1645.79015269 m 1601.46180134 m
#   4%|▍         | 54/1261 [00:23<08:07,  2.48it/s]
# 1652.81837338 m 1934.61577927 m
#   4%|▍         | 55/1261 [00:23<08:07,  2.48it/s]
# 1925.2395097 m 1993.69296202 m
#   4%|▍         | 56/1261 [00:24<08:06,  2.48it/s]
# 1713.7118966 m 3347.34967131 m
#   5%|▍         | 57/1261 [00:24<07:59,  2.51it/s]
# 2335.13799118 m 3460.63915884 m
#   5%|▍         | 58/1261 [00:24<07:58,  2.51it/s]
# 2742.88906404 m 3949.11527785 m
#   5%|▍         | 59/1261 [00:25<08:36,  2.33it/s]
# 2852.14227931 m 1314.61530774 m
#   5%|▍         | 60/1261 [00:25<08:43,  2.29it/s]
# 4485.83721811 m 95316.0534938 m
#   5%|▍         | 61/1261 [00:26<08:45,  2.28it/s]
# 5010.29410733 m 5711.48167145 m
#   5%|▍         | 62/1261 [00:26<08:57,  2.23it/s]
# 49442.0986483 m 1214.40851642 m
#   5%|▍         | 63/1261 [00:27<08:54,  2.24it/s]
# 216640.709649 m 943.763778303 m
#   5%|▌         | 64/1261 [00:27<08:39,  2.30it/s]
# 15877.2426412 m 1345.29084597 m
#   5%|▌         | 65/1261 [00:28<08:25,  2.37it/s]
# 6587.78095905 m 1677.32069091 m
#   5%|▌         | 66/1261 [00:28<08:45,  2.27it/s]
# 4540.33762473 m 1962.61840676 m
#   5%|▌         | 67/1261 [00:28<08:53,  2.24it/s]
# 3784.73398912 m 2948.92508275 m
#   5%|▌         | 68/1261 [00:29<09:06,  2.18it/s]
# 2686.33581485 m 7425.74362622 m
#   5%|▌         | 69/1261 [00:29<09:12,  2.16it/s]
# 2122.51768449 m 6709.09151473 m
#   6%|▌         | 70/1261 [00:30<09:12,  2.16it/s]
# 2235.98432822 m 2315.74544983 m
#   6%|▌         | 71/1261 [00:30<09:12,  2.15it/s]
# 2134.16628119 m 4479.79007764 m
#   6%|▌         | 72/1261 [00:31<09:12,  2.15it/s]
# 1994.92007922 m 9626.26733552 m
#   6%|▌         | 73/1261 [00:31<09:07,  2.17it/s]
# 1800.48875449 m 8975.87044606 m
#   6%|▌         | 74/1261 [00:32<09:07,  2.17it/s]
# 2200.0885572 m 5181.3979467 m
#   6%|▌         | 75/1261 [00:32<09:04,  2.18it/s]
# 2260.000848 m 17905.2637974 m
#   6%|▌         | 76/1261 [00:33<09:06,  2.17it/s]
# 2866.37466593 m 1065.55492422 m
#   6%|▌         | 77/1261 [00:33<09:03,  2.18it/s]
# 4007.34290254 m 1486.99302754 m
#   6%|▌         | 78/1261 [00:34<09:05,  2.17it/s]
# 4591.98317552 m 1786.42902894 m
#   6%|▋         | 79/1261 [00:34<08:58,  2.20it/s]
# 4321.23577201 m 1819.28986179 m
#   6%|▋         | 80/1261 [00:35<09:01,  2.18it/s]
# 7860.01641211 m 2201.62379961 m
#   6%|▋         | 81/1261 [00:35<09:08,  2.15it/s]
# 8152.96488434 m 4751.47295309 m
#   7%|▋         | 82/1261 [00:35<09:02,  2.17it/s]
# 6544.5604303 m 4194.45497697 m
#   7%|▋         | 83/1261 [00:36<09:10,  2.14it/s]
# 11305.8222872 m 7653.1468021 m
#   7%|▋         | 84/1261 [00:36<09:08,  2.15it/s]
# 20674.3581052 m 3612.28261585 m
#   7%|▋         | 85/1261 [00:37<09:20,  2.10it/s]
# 99851.4532999 m 1143.0987426 m
#   7%|▋         | 86/1261 [00:37<09:15,  2.12it/s]
# 18705.1855964 m 3646.93425133 m
#   7%|▋         | 87/1261 [00:38<09:13,  2.12it/s]
# 7411.89774044 m 31375.9734196 m
#   7%|▋         | 88/1261 [00:38<09:10,  2.13it/s]
# 10288.2317503 m 1794.10257761 m
#   7%|▋         | 89/1261 [00:39<09:06,  2.14it/s]
# 15439.9794882 m 860.714495504 m
#   7%|▋         | 90/1261 [00:39<08:58,  2.18it/s]
# 6585.40918996 m 1292.55160735 m
#   7%|▋         | 91/1261 [00:40<08:56,  2.18it/s]
# 3633.90603614 m 2038.04045793 m
#   7%|▋         | 92/1261 [00:40<08:52,  2.19it/s]
# 3126.36264873 m 2858.3208738 m
#   7%|▋         | 93/1261 [00:41<08:57,  2.17it/s]
# 2323.33093273 m 5783.20673684 m
#   7%|▋         | 94/1261 [00:41<08:54,  2.18it/s]
# 2350.9931957 m 27558.2375457 m
#   8%|▊         | 95/1261 [00:41<08:50,  2.20it/s]
# 2296.59201416 m 78979.3048153 m
#   8%|▊         | 96/1261 [00:42<09:00,  2.16it/s]
# 1992.59714333 m 27584.9992084 m
#   8%|▊         | 97/1261 [00:42<09:07,  2.13it/s]
# 2489.04002065 m 4366.85609643 m
#   8%|▊         | 98/1261 [00:43<09:05,  2.13it/s]
# 2319.90164328 m 7134.15525632 m
#   8%|▊         | 99/1261 [00:43<09:01,  2.15it/s]
# 2084.50407959 m 10636.1769032 m
#   8%|▊         | 100/1261 [00:44<09:02,  2.14it/s]
# 2315.03885867 m 13191.2712392 m
#   8%|▊         | 101/1261 [00:44<08:56,  2.16it/s]
# 3679.58939118 m 916.222137743 m
#   8%|▊         | 102/1261 [00:45<08:51,  2.18it/s]
# 2823.61626775 m 1424.37992533 m
#   8%|▊         | 103/1261 [00:45<08:43,  2.21it/s]
# 2543.6892533 m 1727.94361865 m
#   8%|▊         | 104/1261 [00:46<08:44,  2.21it/s]
# 2981.13673106 m 1720.57751414 m
#   8%|▊         | 105/1261 [00:46<08:42,  2.21it/s]
# 2739.64014628 m 2190.95006979 m
#   8%|▊         | 106/1261 [00:47<08:39,  2.22it/s]
# 2550.59849127 m 3222.02102549 m
#   8%|▊         | 107/1261 [00:47<08:45,  2.19it/s]
# 4052.76764392 m 3657.6165967 m
#   9%|▊         | 108/1261 [00:47<08:39,  2.22it/s]
# 2470.83429375 m 3588.5250829 m
#   9%|▊         | 109/1261 [00:48<08:40,  2.22it/s]
# 3119.52282627 m 2568.88567994 m
#   9%|▊         | 110/1261 [00:48<08:32,  2.24it/s]
# 2317.41631369 m 1798.38567917 m
#   9%|▉         | 111/1261 [00:49<08:36,  2.23it/s]
# 2537.87107784 m 59220.9781366 m
#   9%|▉         | 112/1261 [00:49<08:33,  2.24it/s]
# 2752.40519135 m 13714.8944132 m
#   9%|▉         | 113/1261 [00:50<08:35,  2.23it/s]
# 3080.67502931 m 17003.0832945 m
#   9%|▉         | 114/1261 [00:50<08:30,  2.25it/s]
# 4462.17486041 m 1275.37695868 m
#   9%|▉         | 115/1261 [00:51<08:27,  2.26it/s]
# 2812.57245432 m 1720.46193173 m
#   9%|▉         | 116/1261 [00:51<08:27,  2.25it/s]
# 2496.06248081 m 2570.43304126 m
#   9%|▉         | 117/1261 [00:51<08:28,  2.25it/s]
# 2000.72041046 m 1999.83356158 m
#   9%|▉         | 118/1261 [00:52<08:25,  2.26it/s]
# 2068.30445384 m 2707.27502343 m
#   9%|▉         | 119/1261 [00:52<08:27,  2.25it/s]
# 2289.61861784 m 3910.24414965 m
#  10%|▉         | 120/1261 [00:53<08:31,  2.23it/s]
# 2329.79370573 m 3420.00889522 m
#  10%|▉         | 121/1261 [00:53<08:31,  2.23it/s]
# 2173.88693963 m 5523.02008405 m
#  10%|▉         | 122/1261 [00:54<08:30,  2.23it/s]
# 2188.50616129 m 1022.18321679 m
#  10%|▉         | 123/1261 [00:54<08:27,  2.24it/s]
# 2194.37480724 m 1982.15674528 m
#  10%|▉         | 124/1261 [00:55<08:25,  2.25it/s]
# 2287.496288 m 3264.80964063 m
#  10%|▉         | 125/1261 [00:55<08:24,  2.25it/s]
# 2468.47721863 m 1739.01636225 m
#  10%|▉         | 126/1261 [00:55<08:19,  2.27it/s]
# 2543.61789021 m 1011.81654985 m
#  10%|█         | 127/1261 [00:56<08:18,  2.27it/s]
# 2282.58607051 m 934.074972527 m
#  10%|█         | 128/1261 [00:56<08:27,  2.23it/s]
# 2189.48953987 m 1798.29478021 m
#  10%|█         | 129/1261 [00:57<08:34,  2.20it/s]
# 1802.59567791 m 1870.4951491 m
#  10%|█         | 130/1261 [00:57<08:34,  2.20it/s]
# 1699.97317146 m 2502.06623951 m
#  10%|█         | 131/1261 [00:58<08:27,  2.23it/s]
# 1849.62160653 m 3703.57437899 m
#  10%|█         | 132/1261 [00:58<08:25,  2.23it/s]
# 1852.19882535 m 2480.18071669 m
#  11%|█         | 133/1261 [00:59<08:24,  2.24it/s]
# 1977.56587568 m 1957.10979993 m
#  11%|█         | 134/1261 [00:59<08:22,  2.24it/s]
# 2353.01121971 m 1067.38701805 m
#  11%|█         | 135/1261 [00:59<08:19,  2.25it/s]
# 2625.67874354 m 1884.79972965 m
#  11%|█         | 136/1261 [01:00<08:07,  2.31it/s]
# 2811.81999822 m 28938.7013461 m
#  11%|█         | 137/1261 [01:00<07:52,  2.38it/s]
# 4049.3431542 m 3463.24004323 m
#  11%|█         | 138/1261 [01:01<07:40,  2.44it/s]
# 5806.17164772 m 1765.14126018 m
#  11%|█         | 139/1261 [01:01<07:32,  2.48it/s]
# 5890.13878876 m 1196.25005841 m
#  11%|█         | 140/1261 [01:01<07:28,  2.50it/s]
# 7781.52500133 m 1197.20806546 m
#  11%|█         | 141/1261 [01:02<07:23,  2.52it/s]
# 6262.38974129 m 1580.47586155 m
#  11%|█▏        | 142/1261 [01:02<07:24,  2.52it/s]
# 4723.32119975 m 1815.69048709 m
#  11%|█▏        | 143/1261 [01:03<07:26,  2.50it/s]
# 3711.25287168 m 2193.42848097 m
#  11%|█▏        | 144/1261 [01:03<07:26,  2.50it/s]
# 3377.84993846 m 2792.4857118 m
#  11%|█▏        | 145/1261 [01:03<07:20,  2.53it/s]
# 3182.95018086 m 3652.15002485 m
#  12%|█▏        | 146/1261 [01:04<07:16,  2.55it/s]
# 2751.44277532 m 1174.98906057 m
#  12%|█▏        | 147/1261 [01:04<07:15,  2.56it/s]
# 2586.38714857 m 1482.11993448 m
#  12%|█▏        | 148/1261 [01:05<07:12,  2.57it/s]
# 2304.97404458 m 3110.79105311 m
#  12%|█▏        | 149/1261 [01:05<07:12,  2.57it/s]
# 2304.58963783 m 11935.1708809 m
#  12%|█▏        | 150/1261 [01:05<07:12,  2.57it/s]
# 4623.601623 m 9918.82804861 m
#  12%|█▏        | 151/1261 [01:06<07:14,  2.56it/s]
# 2785.04866668 m 1113.93630538 m
#  12%|█▏        | 152/1261 [01:06<07:17,  2.53it/s]
# 5132.44473802 m 1226.1337571 m
#  12%|█▏        | 153/1261 [01:07<07:11,  2.57it/s]
# 4668.95089854 m 2338.038049 m
#  12%|█▏        | 154/1261 [01:07<07:15,  2.54it/s]
# 3802.32106891 m 3272.78296905 m
#  12%|█▏        | 155/1261 [01:07<07:13,  2.55it/s]
# 5413.18281459 m 3588.67000367 m
#  12%|█▏        | 156/1261 [01:08<07:12,  2.56it/s]
# 5597.69831968 m 5473.38812483 m
#  12%|█▏        | 157/1261 [01:08<07:17,  2.52it/s]
# 3894.78324444 m 8740.29141272 m
#  13%|█▎        | 158/1261 [01:08<07:15,  2.53it/s]
# 9193.27549331 m 1709.97187297 m
#  13%|█▎        | 159/1261 [01:09<07:18,  2.51it/s]
# 3910.33252989 m 808.340011031 m
#  13%|█▎        | 160/1261 [01:09<07:18,  2.51it/s]
# 4321.02012675 m 1393.60057442 m
#  13%|█▎        | 161/1261 [01:10<07:16,  2.52it/s]
# 3313.27514496 m 3034.4742728 m
#  13%|█▎        | 162/1261 [01:10<07:11,  2.55it/s]
# 3043.97834036 m 2506.85586825 m
#  13%|█▎        | 163/1261 [01:10<07:08,  2.56it/s]
# 2912.10237127 m 2036.32552621 m
#  13%|█▎        | 164/1261 [01:11<07:07,  2.57it/s]
# 2581.44000393 m 1135.8893227 m
#  13%|█▎        | 165/1261 [01:11<07:04,  2.58it/s]
# 2624.00072979 m 2367.73058311 m
#  13%|█▎        | 166/1261 [01:12<07:03,  2.59it/s]
# 2613.17633545 m 2633.48314721 m
#  13%|█▎        | 167/1261 [01:12<07:05,  2.57it/s]
# 2834.06326951 m 5984.96818936 m
#  13%|█▎        | 168/1261 [01:12<07:03,  2.58it/s]
# 2112.67457569 m 18174.0000917 m
#  13%|█▎        | 169/1261 [01:13<07:08,  2.55it/s]
# 2552.84436854 m 68179.7776521 m
#  13%|█▎        | 170/1261 [01:13<07:06,  2.56it/s]
# 2373.6195979 m 12933.8013059 m
#  14%|█▎        | 171/1261 [01:14<07:04,  2.57it/s]
# 2733.63384754 m 2102.97156168 m
#  14%|█▎        | 172/1261 [01:14<07:10,  2.53it/s]
# 2646.5729825 m 1095.59784338 m
#  14%|█▎        | 173/1261 [01:14<07:09,  2.54it/s]
# 2455.28216517 m 2870.54303625 m
#  14%|█▍        | 174/1261 [01:15<07:09,  2.53it/s]
# 2434.25692905 m 4359.10939083 m
#  14%|█▍        | 175/1261 [01:15<07:10,  2.52it/s]
# 2922.25130798 m 3122.61746271 m
#  14%|█▍        | 176/1261 [01:16<07:09,  2.53it/s]
# 3078.86785237 m 1068.48130158 m
#  14%|█▍        | 177/1261 [01:16<07:08,  2.53it/s]
# 3879.42631663 m 1512.29263697 m
#  14%|█▍        | 178/1261 [01:16<07:09,  2.52it/s]
# 5193.27286707 m 1456.43889711 m
#  14%|█▍        | 179/1261 [01:17<07:10,  2.51it/s]
# 6087.71449763 m 1685.33212091 m
#  14%|█▍        | 180/1261 [01:17<07:10,  2.51it/s]
# 9309.25729902 m 1844.35837234 m
#  14%|█▍        | 181/1261 [01:18<07:07,  2.52it/s]
# 12737.7681161 m 2887.24643663 m
#  14%|█▍        | 182/1261 [01:18<07:09,  2.51it/s]
# 10088.3420518 m 2448.95083481 m
#  15%|█▍        | 183/1261 [01:18<07:08,  2.52it/s]
# 7062.28744205 m 1708.96299008 m
#  15%|█▍        | 184/1261 [01:19<07:13,  2.49it/s]
# 13608.9381333 m 839.600083915 m
#  15%|█▍        | 185/1261 [01:19<07:08,  2.51it/s]
# 3907.48599699 m 1312.48206472 m
#  15%|█▍        | 186/1261 [01:20<07:08,  2.51it/s]
# 2755.94021462 m 1099.73653281 m
#  15%|█▍        | 187/1261 [01:20<07:12,  2.48it/s]
# 2098.95098677 m 978.543916797 m
#  15%|█▍        | 188/1261 [01:20<07:09,  2.50it/s]
# 1711.44626121 m 1217.16539271 m
#  15%|█▍        | 189/1261 [01:21<07:08,  2.50it/s]
# 1674.55439158 m 1607.34627198 m
#  15%|█▌        | 190/1261 [01:21<07:14,  2.47it/s]
# 1502.97405434 m 1372.08037759 m
#  15%|█▌        | 191/1261 [01:22<07:09,  2.49it/s]
# 1464.31857096 m 2252.32164814 m
#  15%|█▌        | 192/1261 [01:22<07:08,  2.50it/s]
# 1574.04139539 m 2232.68280084 m
#  15%|█▌        | 193/1261 [01:22<07:05,  2.51it/s]
# 1710.26949994 m 4025.52681104 m
#  15%|█▌        | 194/1261 [01:23<07:04,  2.51it/s]
# 2344.61906824 m 1289.27781725 m
#  15%|█▌        | 195/1261 [01:23<07:04,  2.51it/s]
# 2115.73886097 m 1162.73471403 m
#  16%|█▌        | 196/1261 [01:24<06:58,  2.54it/s]
# 2927.18540409 m 1247.40692352 m
#  16%|█▌        | 197/1261 [01:24<07:01,  2.52it/s]
# 2962.68996656 m 1462.04169257 m
#  16%|█▌        | 198/1261 [01:24<06:58,  2.54it/s]
# 2754.18086479 m 3141.35869026 m
#  16%|█▌        | 199/1261 [01:25<06:59,  2.53it/s]
# 2913.42993898 m 6994.3091329 m
#  16%|█▌        | 200/1261 [01:25<06:56,  2.55it/s]
# 3179.29921382 m 7662.20708899 m
#  16%|█▌        | 201/1261 [01:25<06:52,  2.57it/s]
# 3519.86468296 m 2679.67799523 m
#  16%|█▌        | 202/1261 [01:26<06:52,  2.57it/s]
# 3276.05187595 m 976.431459901 m
#  16%|█▌        | 203/1261 [01:26<06:56,  2.54it/s]
# 2758.56212062 m 2273.51676231 m
#  16%|█▌        | 204/1261 [01:27<06:55,  2.54it/s]
# 2679.24803998 m 2016.55287107 m
#  16%|█▋        | 205/1261 [01:27<07:01,  2.50it/s]
# 3508.39249587 m 2296.01121761 m
#  16%|█▋        | 206/1261 [01:27<06:55,  2.54it/s]
# 3148.23251189 m 4314.76340637 m
#  16%|█▋        | 207/1261 [01:28<06:53,  2.55it/s]
# 3391.80998958 m 2875.45915816 m
#  16%|█▋        | 208/1261 [01:28<06:49,  2.57it/s]
# 4473.15507438 m 857.025981684 m
#  17%|█▋        | 209/1261 [01:29<06:53,  2.55it/s]
# 3192.57284742 m 1211.39878698 m
#  17%|█▋        | 210/1261 [01:29<06:51,  2.56it/s]
# 3835.04825733 m 2385.7757731 m
#  17%|█▋        | 211/1261 [01:29<06:49,  2.57it/s]
# 4731.78141044 m 2967.20002869 m
#  17%|█▋        | 212/1261 [01:30<06:48,  2.57it/s]
# 3556.68280713 m 4391.08460917 m
#  17%|█▋        | 213/1261 [01:30<06:51,  2.55it/s]
# 3731.66236382 m 1820.25748865 m
#  17%|█▋        | 214/1261 [01:31<06:48,  2.57it/s]
# 2937.31251862 m 1043.80687706 m
#  17%|█▋        | 215/1261 [01:31<06:49,  2.56it/s]
# 2386.5242289 m 1590.74413274 m
#  17%|█▋        | 216/1261 [01:31<06:45,  2.57it/s]
# 1980.91899015 m 1544.87917071 m
#  17%|█▋        | 217/1261 [01:32<06:57,  2.50it/s]
# 1711.62200443 m 2088.00763803 m
#  17%|█▋        | 218/1261 [01:32<06:53,  2.52it/s]
# 1659.74325493 m 3685.14975182 m
#  17%|█▋        | 219/1261 [01:33<06:57,  2.50it/s]
# 1785.30797213 m 3633.38156868 m
#  17%|█▋        | 220/1261 [01:33<06:54,  2.51it/s]
# 1976.16972053 m 1556.81785293 m
#  18%|█▊        | 221/1261 [01:33<06:46,  2.56it/s]
# 2070.83370652 m 935.805736833 m
#  18%|█▊        | 222/1261 [01:34<06:42,  2.58it/s]
# 2683.91077373 m 1312.3267613 m
#  18%|█▊        | 223/1261 [01:34<06:47,  2.55it/s]
# 2390.7435854 m 3058.18524088 m
#  18%|█▊        | 224/1261 [01:35<06:48,  2.54it/s]
# 3501.69948275 m 3939.26478794 m
#  18%|█▊        | 225/1261 [01:35<06:46,  2.55it/s]
# 2735.5698581 m 1140.33766045 m
#  18%|█▊        | 226/1261 [01:35<06:45,  2.55it/s]
# 2334.67015108 m 1693.20539463 m
#  18%|█▊        | 227/1261 [01:36<06:41,  2.57it/s]
# 2425.9409102 m 3468.06713893 m
#  18%|█▊        | 228/1261 [01:36<06:48,  2.53it/s]
# 2570.4289725 m 3220.89237887 m
#  18%|█▊        | 229/1261 [01:36<06:43,  2.56it/s]
# 2474.16049522 m 4601.65469787 m
#  18%|█▊        | 230/1261 [01:37<06:49,  2.52it/s]
# 2680.5193295 m 8964.098053 m
#  18%|█▊        | 231/1261 [01:37<06:49,  2.51it/s]
# 3294.54325619 m 8153.86820392 m
#  18%|█▊        | 232/1261 [01:38<06:49,  2.51it/s]
# 3134.51277044 m 5710.65997149 m
#  18%|█▊        | 233/1261 [01:38<06:42,  2.55it/s]
# 4600.76464411 m 1637.11071995 m
#  19%|█▊        | 234/1261 [01:38<06:40,  2.57it/s]
# 4776.77853648 m 2900.33580493 m
#  19%|█▊        | 235/1261 [01:39<06:38,  2.58it/s]
# 4706.48855812 m 3113.63403994 m
#  19%|█▊        | 236/1261 [01:39<06:37,  2.58it/s]
# 4838.60171494 m 7669.3245958 m
#  19%|█▉        | 237/1261 [01:40<06:36,  2.58it/s]
# 4557.08492579 m 1266.1859302 m
#  19%|█▉        | 238/1261 [01:40<06:40,  2.55it/s]
# 4864.3782143 m 944.553789007 m
#  19%|█▉        | 239/1261 [01:40<06:42,  2.54it/s]
# 4587.22873839 m 1494.97148845 m
#  19%|█▉        | 240/1261 [01:41<06:45,  2.52it/s]
# 4850.00238015 m 1349.98554832 m
#  19%|█▉        | 241/1261 [01:41<06:59,  2.43it/s]
# 4356.42927628 m 1958.52495282 m
#  19%|█▉        | 242/1261 [01:42<06:51,  2.48it/s]
# 4226.79261994 m 2097.63185062 m
#  19%|█▉        | 243/1261 [01:42<06:46,  2.50it/s]
# 6515.03339702 m 2739.15343527 m
#  19%|█▉        | 244/1261 [01:42<06:46,  2.50it/s]
# 3711.06052812 m 2011.74444711 m
#  19%|█▉        | 245/1261 [01:43<06:49,  2.48it/s]
# 4760.14137974 m 1498.69594035 m
#  20%|█▉        | 246/1261 [01:43<06:48,  2.49it/s]
# 3978.66227139 m 1991.17766692 m
#  20%|█▉        | 247/1261 [01:44<06:50,  2.47it/s]
# 3508.87438718 m 3337.77929104 m
#  20%|█▉        | 248/1261 [01:44<06:45,  2.50it/s]
# 3343.06199831 m 1181.26516953 m
#  20%|█▉        | 249/1261 [01:44<06:40,  2.53it/s]
# 3114.65598098 m 867.781335432 m
#  20%|█▉        | 250/1261 [01:45<06:40,  2.52it/s]
# 2978.7336894 m 1585.83932934 m
#  20%|█▉        | 251/1261 [01:45<06:36,  2.55it/s]
# 2756.62661132 m 1055.74984466 m
#  20%|█▉        | 252/1261 [01:46<06:36,  2.55it/s]
# 2527.29620547 m 1503.90689153 m
#  20%|██        | 253/1261 [01:46<06:35,  2.55it/s]
# 2538.60916162 m 1544.48824416 m
#  20%|██        | 254/1261 [01:46<06:40,  2.52it/s]
# 2549.87586771 m 2501.25941791 m
#  20%|██        | 255/1261 [01:47<06:40,  2.51it/s]
# 3922.93477103 m 4828.5218704 m
#  20%|██        | 256/1261 [01:47<06:40,  2.51it/s]
# 2746.84581408 m 2344.47303527 m
#  20%|██        | 257/1261 [01:48<06:37,  2.52it/s]
# 3572.08826274 m 889.613262079 m
#  20%|██        | 258/1261 [01:48<06:33,  2.55it/s]
# 3415.14003794 m 2836.10820573 m
#  21%|██        | 259/1261 [01:48<06:32,  2.55it/s]
# 3749.21600964 m 2048.80223842 m
#  21%|██        | 260/1261 [01:49<06:33,  2.54it/s]
# 3800.80210434 m 4198.29627574 m
#  21%|██        | 261/1261 [01:49<06:29,  2.57it/s]
# 4236.43010242 m 1233.57546561 m
#  21%|██        | 262/1261 [01:50<06:30,  2.56it/s]
# 4987.18974663 m 935.223175336 m
#  21%|██        | 263/1261 [01:50<06:30,  2.56it/s]
# 4218.07524033 m 1423.4394185 m
#  21%|██        | 264/1261 [01:50<06:32,  2.54it/s]
# 3938.84830378 m 1880.55939237 m
#  21%|██        | 265/1261 [01:51<06:32,  2.54it/s]
# 4688.36954741 m 2340.03924565 m
#  21%|██        | 266/1261 [01:51<06:32,  2.54it/s]
# 3149.81507599 m 2935.61066114 m
#  21%|██        | 267/1261 [01:52<06:34,  2.52it/s]
# 3255.21738051 m 2874.86896718 m
#  21%|██▏       | 268/1261 [01:52<06:39,  2.49it/s]
# 2562.3055482 m 2968.69689203 m
#  21%|██▏       | 269/1261 [01:52<06:39,  2.48it/s]
# 3141.94847131 m 1885.91525468 m
#  21%|██▏       | 270/1261 [01:53<06:37,  2.49it/s]
# 4090.37631368 m 1788.83321412 m
#  21%|██▏       | 271/1261 [01:53<06:36,  2.49it/s]
# 3485.21877414 m 4291.69094874 m
#  22%|██▏       | 272/1261 [01:54<06:32,  2.52it/s]
# 4139.49923427 m 3259.58061637 m
#  22%|██▏       | 273/1261 [01:54<06:27,  2.55it/s]
# 3637.82025265 m 1383.51508757 m
#  22%|██▏       | 274/1261 [01:54<06:27,  2.55it/s]
# 2937.85254603 m 1302.84230685 m
#  22%|██▏       | 275/1261 [01:55<06:25,  2.55it/s]
# 2934.67306393 m 1782.88475293 m
#  22%|██▏       | 276/1261 [01:55<06:23,  2.57it/s]
# 2718.19043949 m 2567.00722792 m
#  22%|██▏       | 277/1261 [01:55<06:19,  2.59it/s]
# 3225.24419342 m 3433.16748651 m
#  22%|██▏       | 278/1261 [01:56<06:22,  2.57it/s]
# 3111.28483523 m 4841.31865886 m
#  22%|██▏       | 279/1261 [01:56<06:20,  2.58it/s]
# 3291.35568365 m 9833.26695108 m
#  22%|██▏       | 280/1261 [01:57<06:21,  2.57it/s]
# 3900.20234783 m 2500.56976389 m
#  22%|██▏       | 281/1261 [01:57<06:24,  2.55it/s]
# 4540.24665216 m 909.814997471 m
#  22%|██▏       | 282/1261 [01:57<06:26,  2.53it/s]
# 4144.49423243 m 1805.20328339 m
#  22%|██▏       | 283/1261 [01:58<06:27,  2.53it/s]
# 3473.57544 m 3561.47594682 m
#  23%|██▎       | 284/1261 [01:58<06:25,  2.53it/s]
# 3542.26511219 m 2465.27762446 m
#  23%|██▎       | 285/1261 [01:59<06:31,  2.49it/s]
# 3520.07264989 m 1976.62183587 m
#  23%|██▎       | 286/1261 [01:59<06:26,  2.52it/s]
# 4356.25200498 m 1229.52901728 m
#  23%|██▎       | 287/1261 [01:59<06:24,  2.53it/s]
# 4544.80788927 m 2383.55420785 m
#  23%|██▎       | 288/1261 [02:00<06:21,  2.55it/s]
# 3983.41242637 m 3284.99378966 m
#  23%|██▎       | 289/1261 [02:00<06:24,  2.53it/s]
# 3733.92532527 m 3007.82982496 m
#  23%|██▎       | 290/1261 [02:01<06:21,  2.54it/s]
# 3648.89261316 m 11413.3447151 m
#  23%|██▎       | 291/1261 [02:01<06:23,  2.53it/s]
# 4022.77122699 m 16425.9258695 m
#  23%|██▎       | 292/1261 [02:01<06:21,  2.54it/s]
# 3213.17793676 m 3203.77440663 m
#  23%|██▎       | 293/1261 [02:02<06:25,  2.51it/s]
# 4164.67951382 m 1250.51121639 m
#  23%|██▎       | 294/1261 [02:02<06:20,  2.54it/s]
# 4136.78354494 m 1836.28605928 m
#  23%|██▎       | 295/1261 [02:03<06:15,  2.57it/s]
# 5804.01799135 m 7505.80430913 m
#  23%|██▎       | 296/1261 [02:03<06:21,  2.53it/s]
# 5983.24913486 m 2384.06771751 m
#  24%|██▎       | 297/1261 [02:03<06:21,  2.53it/s]
# 5527.90718991 m 3015.48374476 m
#  24%|██▎       | 298/1261 [02:04<06:21,  2.52it/s]
# 13254.5919232 m 1731.16390722 m
#  24%|██▎       | 299/1261 [02:04<06:20,  2.53it/s]
# 13857.0624574 m 2828.59244765 m
#  24%|██▍       | 300/1261 [02:05<06:21,  2.52it/s]
# 5894.7042674 m 2111.48857151 m
#  24%|██▍       | 301/1261 [02:05<06:21,  2.51it/s]
# 6616.82638976 m 2667.01285576 m
#  24%|██▍       | 302/1261 [02:05<06:19,  2.53it/s]
# 5236.27741967 m 5014.77598742 m
#  24%|██▍       | 303/1261 [02:06<06:18,  2.53it/s]
# 4430.11741289 m 6099.76826273 m
#  24%|██▍       | 304/1261 [02:06<06:19,  2.52it/s]
# 5542.70875316 m 5787.37096804 m
#  24%|██▍       | 305/1261 [02:07<06:21,  2.51it/s]
# 4095.0848571 m 4159.46572093 m
#  24%|██▍       | 306/1261 [02:07<06:23,  2.49it/s]
# 5922.34375402 m 2142.60315301 m
#  24%|██▍       | 307/1261 [02:07<06:21,  2.50it/s]
# 5795.45132231 m 2820.64593371 m
#  24%|██▍       | 308/1261 [02:08<06:22,  2.49it/s]
# 6717.31141783 m 87910.9813739 m
#  25%|██▍       | 309/1261 [02:08<06:18,  2.51it/s]
# 9402.35891077 m 4605.84284618 m
#  25%|██▍       | 310/1261 [02:09<06:20,  2.50it/s]
# 38878.8644393 m 1980.8696091 m
#  25%|██▍       | 311/1261 [02:09<06:19,  2.51it/s]
# 17913.1556174 m 2092.11450261 m
#  25%|██▍       | 312/1261 [02:09<06:13,  2.54it/s]
# 12089.0012252 m 6207.20302267 m
#  25%|██▍       | 313/1261 [02:10<06:10,  2.56it/s]
# 19905.0629813 m 24493.2889298 m
#  25%|██▍       | 314/1261 [02:10<06:13,  2.53it/s]
# 11381.0904018 m 3020.52460533 m
#  25%|██▍       | 315/1261 [02:11<06:13,  2.53it/s]
# 109789.369054 m 7709.85888965 m
#  25%|██▌       | 316/1261 [02:11<06:11,  2.55it/s]
# 38379.594744 m 13513.9767635 m
#  25%|██▌       | 317/1261 [02:11<06:13,  2.53it/s]
# 166683.75709 m 2681.42501308 m
#  25%|██▌       | 318/1261 [02:12<06:11,  2.54it/s]
# 22358.7864312 m 5275.32512021 m
#  25%|██▌       | 319/1261 [02:12<06:16,  2.50it/s]
# 21775.3994004 m 41771.7355358 m
#  25%|██▌       | 320/1261 [02:12<06:10,  2.54it/s]
# 83401.7387183 m 3912.55875674 m
#  25%|██▌       | 321/1261 [02:13<06:15,  2.50it/s]
# 55485.6817034 m 3765.26788481 m
#  26%|██▌       | 322/1261 [02:13<06:10,  2.53it/s]
# 46229.9868955 m 1928.93310429 m
#  26%|██▌       | 323/1261 [02:14<06:14,  2.50it/s]
# 24966.4134829 m 4313.8341489 m
#  26%|██▌       | 324/1261 [02:14<06:11,  2.53it/s]
# 19065.332162 m 2630.78917605 m
#  26%|██▌       | 325/1261 [02:14<06:13,  2.51it/s]
# 29090.1848939 m 4140.15608952 m
#  26%|██▌       | 326/1261 [02:15<06:08,  2.54it/s]
# 28702.3902364 m 32628.9786953 m
#  26%|██▌       | 327/1261 [02:15<06:06,  2.55it/s]
# 42005.9592136 m 12255.5647948 m
#  26%|██▌       | 328/1261 [02:16<06:05,  2.55it/s]
# 33296.0224377 m 15948.1636604 m
#  26%|██▌       | 329/1261 [02:16<06:02,  2.57it/s]
# 292957.205571 m 2726.41438557 m
#  26%|██▌       | 330/1261 [02:16<06:01,  2.57it/s]
# 12023.9262214 m 15667.8270159 m
#  26%|██▌       | 331/1261 [02:17<06:06,  2.53it/s]
# 8848.46497294 m 6518.54923731 m
#  26%|██▋       | 332/1261 [02:17<06:12,  2.49it/s]
# 8972.41961972 m 347376.267995 m
#  26%|██▋       | 333/1261 [02:18<06:09,  2.51it/s]
# 7039.24804932 m 1911.47817722 m
#  26%|██▋       | 334/1261 [02:18<06:06,  2.53it/s]
# 5514.67184597 m 2060.56768516 m
#  27%|██▋       | 335/1261 [02:18<06:05,  2.54it/s]
# 7018.36141679 m 2142.84454072 m
#  27%|██▋       | 336/1261 [02:19<06:07,  2.51it/s]
# 8567.7339291 m 1748.88197145 m
#  27%|██▋       | 337/1261 [02:19<06:06,  2.52it/s]
# 11125.9440334 m 5786.78231454 m
#  27%|██▋       | 338/1261 [02:20<06:02,  2.54it/s]
# 14487.0950332 m 191198.907916 m
#  27%|██▋       | 339/1261 [02:20<06:07,  2.51it/s]
# 22934.2166236 m 10952.9440308 m
#  27%|██▋       | 340/1261 [02:20<06:07,  2.51it/s]
# 11303.2267124 m 5963.90631672 m
#  27%|██▋       | 341/1261 [02:21<06:01,  2.55it/s]
# 24593.1915961 m 7831.60227324 m
#  27%|██▋       | 342/1261 [02:21<06:00,  2.55it/s]
# 35193.6926341 m 9865.30141806 m
#  27%|██▋       | 343/1261 [02:22<06:06,  2.50it/s]
# 19834.7671625 m 3064.9343026 m
#  27%|██▋       | 344/1261 [02:22<06:07,  2.49it/s]
# 61379.4532934 m 4641.343834 m
#  27%|██▋       | 345/1261 [02:22<06:03,  2.52it/s]
# 216244.720504 m 8054.57663594 m
#  27%|██▋       | 346/1261 [02:23<06:01,  2.53it/s]
# 32275.4190516 m 1662.81668226 m
#  28%|██▊       | 347/1261 [02:23<06:00,  2.54it/s]
# 9315.73233503 m 2197.51622723 m
#  28%|██▊       | 348/1261 [02:24<05:57,  2.55it/s]
# 8381.24846014 m 3726.52984662 m
#  28%|██▊       | 349/1261 [02:24<05:59,  2.54it/s]
# 5804.23758496 m 7201.20299167 m
#  28%|██▊       | 350/1261 [02:24<05:55,  2.56it/s]
# 4113.69018321 m 12257.6238142 m
#  28%|██▊       | 351/1261 [02:25<05:57,  2.55it/s]
# 5527.09707356 m 8037.21328412 m
#  28%|██▊       | 352/1261 [02:25<05:57,  2.54it/s]
# 3376.28863287 m 5954.40968967 m
#  28%|██▊       | 353/1261 [02:26<06:00,  2.52it/s]
# 4015.0881988 m 68928.5751009 m
#  28%|██▊       | 354/1261 [02:26<05:58,  2.53it/s]
# 4640.74139663 m 2325.17682087 m
#  28%|██▊       | 355/1261 [02:26<05:55,  2.55it/s]
# 6294.00455259 m 95107.1663014 m
#  28%|██▊       | 356/1261 [02:27<06:00,  2.51it/s]
# 11340.2469849 m 4961.19963137 m
#  28%|██▊       | 357/1261 [02:27<06:01,  2.50it/s]
# 26189.8403243 m 13832.6784287 m
#  28%|██▊       | 358/1261 [02:28<05:56,  2.53it/s]
# 553420.991956 m 2597.03276426 m
#  28%|██▊       | 359/1261 [02:28<06:00,  2.50it/s]
# 8384.8303451 m 2363.32185361 m
#  29%|██▊       | 360/1261 [02:28<05:54,  2.54it/s]
# 5976.86254023 m 4016.23775585 m
#  29%|██▊       | 361/1261 [02:29<06:00,  2.50it/s]
# 7905.62219801 m 6364.34996787 m
#  29%|██▊       | 362/1261 [02:29<05:59,  2.50it/s]
# 5073.77261874 m 36141.0153617 m
#  29%|██▉       | 363/1261 [02:30<05:57,  2.51it/s]
# 5515.31985957 m 8281.73970089 m
#  29%|██▉       | 364/1261 [02:30<05:59,  2.50it/s]
# 6937.5449497 m 4950.5067786 m
#  29%|██▉       | 365/1261 [02:30<05:56,  2.51it/s]
# 6398.98404675 m 9236.76677175 m
#  29%|██▉       | 366/1261 [02:31<05:57,  2.50it/s]
# 8929.1520172 m 10362.2435289 m
#  29%|██▉       | 367/1261 [02:31<05:57,  2.50it/s]
# 10911.5970285 m 5288.04835241 m
#  29%|██▉       | 368/1261 [02:31<05:52,  2.53it/s]
# 6552.09695229 m 10488.4702663 m
#  29%|██▉       | 369/1261 [02:32<05:56,  2.50it/s]
# 3397.9628301 m 10726.1560501 m
#  29%|██▉       | 370/1261 [02:32<05:50,  2.54it/s]
# 2647.46035878 m 3910.19750196 m
#  29%|██▉       | 371/1261 [02:33<05:54,  2.51it/s]
# 2837.29711913 m 4039.29059734 m
#  30%|██▉       | 372/1261 [02:33<05:58,  2.48it/s]
# 2636.57344536 m 10027.718438 m
#  30%|██▉       | 373/1261 [02:34<06:04,  2.44it/s]
# 2372.9500335 m 19736.0379295 m
#  30%|██▉       | 374/1261 [02:34<06:02,  2.45it/s]
# 2610.57082448 m 7067.20539572 m
#  30%|██▉       | 375/1261 [02:34<05:55,  2.49it/s]
# 3093.54628626 m 9373.30850125 m
#  30%|██▉       | 376/1261 [02:35<05:56,  2.48it/s]
# 3001.65175654 m 3763.14347644 m
#  30%|██▉       | 377/1261 [02:35<05:53,  2.50it/s]
# 3304.18288117 m 6963.30799904 m
#  30%|██▉       | 378/1261 [02:36<05:50,  2.52it/s]
# 5275.77986783 m 3209.57237658 m
#  30%|███       | 379/1261 [02:36<05:47,  2.53it/s]
# 6138.42553891 m 3481.96967596 m
#  30%|███       | 380/1261 [02:36<05:46,  2.54it/s]
# 6408.31885777 m 4714.87110985 m
#  30%|███       | 381/1261 [02:37<05:46,  2.54it/s]
# 5836.51481529 m 16695.4227 m
#  30%|███       | 382/1261 [02:37<05:50,  2.51it/s]
# 9782.98736107 m 1389.73759678 m
#  30%|███       | 383/1261 [02:38<05:55,  2.47it/s]
# 23183.8683611 m 4511.01085706 m
#  30%|███       | 384/1261 [02:38<05:53,  2.48it/s]
# 50444.7194495 m 6254.12716534 m
#  31%|███       | 385/1261 [02:38<05:50,  2.50it/s]
# 23322.7923299 m 12955.3797253 m
#  31%|███       | 386/1261 [02:39<05:52,  2.48it/s]
# 7147.75259855 m 6531.88833793 m
#  31%|███       | 387/1261 [02:39<05:54,  2.47it/s]
# 4415.50227984 m 5066.4357713 m
#  31%|███       | 388/1261 [02:40<05:49,  2.50it/s]
# 4678.7775521 m 5746.14557566 m
#  31%|███       | 389/1261 [02:40<05:50,  2.49it/s]
# 4056.86513255 m 30785.7788501 m
#  31%|███       | 390/1261 [02:40<05:47,  2.51it/s]
# 7163.91099887 m 5314.8424039 m
#  31%|███       | 391/1261 [02:41<05:46,  2.51it/s]
# 14100.4095362 m 8188.22142079 m
#  31%|███       | 392/1261 [02:41<05:45,  2.52it/s]
# 14384.6436445 m 11664.7416768 m
#  31%|███       | 393/1261 [02:41<05:42,  2.53it/s]
# 17769.0804033 m 3734.43328572 m
#  31%|███       | 394/1261 [02:42<05:48,  2.49it/s]
# 14783.7455983 m 1704.14837203 m
#  31%|███▏      | 395/1261 [02:42<05:48,  2.48it/s]
# 6200.80661611 m 2306.89102307 m
#  31%|███▏      | 396/1261 [02:43<05:48,  2.48it/s]
# 6861.24194185 m 7746.40824138 m
#  31%|███▏      | 397/1261 [02:43<05:46,  2.50it/s]
# 6266.24477537 m 9610.75003846 m
#  32%|███▏      | 398/1261 [02:43<05:40,  2.53it/s]
# 10397.1920252 m 51113.7583251 m
#  32%|███▏      | 399/1261 [02:44<05:45,  2.50it/s]
# 17024.3232182 m 4920.87655023 m
#  32%|███▏      | 400/1261 [02:44<05:41,  2.52it/s]
# 8605.64155959 m 4500.05025748 m
#  32%|███▏      | 401/1261 [02:45<05:39,  2.53it/s]
# 30104.073501 m 3741.75740037 m
#  32%|███▏      | 402/1261 [02:45<05:37,  2.54it/s]
# 16732.0588641 m 46788.3023103 m
#  32%|███▏      | 403/1261 [02:45<05:34,  2.57it/s]
# 10376.4126308 m 27383.4732828 m
#  32%|███▏      | 404/1261 [02:46<05:40,  2.52it/s]
# 12400.645067 m 4100.15913025 m
#  32%|███▏      | 405/1261 [02:46<05:38,  2.53it/s]
# 9237.46073374 m 15714.0781149 m
#  32%|███▏      | 406/1261 [02:47<05:39,  2.52it/s]
# 10174.4286527 m 1593.62680923 m
#  32%|███▏      | 407/1261 [02:47<05:38,  2.52it/s]
# 16434.6724092 m 2299.15799562 m
#  32%|███▏      | 408/1261 [02:47<05:35,  2.54it/s]
# 945128.077693 m 4580.19638008 m
#  32%|███▏      | 409/1261 [02:48<05:40,  2.50it/s]
# 23548.0859261 m 26048.6309384 m
#  33%|███▎      | 410/1261 [02:48<05:38,  2.51it/s]
# 12877.5285933 m 60927.6460464 m
#  33%|███▎      | 411/1261 [02:49<05:39,  2.50it/s]
# 7535.77477218 m 4064.97095252 m
#  33%|███▎      | 412/1261 [02:49<05:39,  2.50it/s]
# 4385.18669479 m 4216.06599329 m
#  33%|███▎      | 413/1261 [02:49<05:38,  2.51it/s]
# 8035.2058382 m 2975.41949422 m
#  33%|███▎      | 414/1261 [02:50<05:40,  2.49it/s]
# 10727.3736689 m 3487.53515791 m
#  33%|███▎      | 415/1261 [02:50<05:38,  2.50it/s]
# 6630.27850122 m 24426.713762 m
#  33%|███▎      | 416/1261 [02:51<05:36,  2.51it/s]
# 10296.0718604 m 8966.76604582 m
#  33%|███▎      | 417/1261 [02:51<05:31,  2.54it/s]
# 11138.4661924 m 5953.66243138 m
#  33%|███▎      | 418/1261 [02:51<05:30,  2.55it/s]
# 25061.0128436 m 5277.29780409 m
#  33%|███▎      | 419/1261 [02:52<05:27,  2.57it/s]
# 250405.126057 m 2758.97247833 m
#  33%|███▎      | 420/1261 [02:52<05:30,  2.54it/s]
# 42552.5702989 m 19377.8103319 m
#  33%|███▎      | 421/1261 [02:53<05:30,  2.54it/s]
# 33483.2339096 m 6162.71309567 m
#  33%|███▎      | 422/1261 [02:53<05:35,  2.50it/s]
# 12291.987887 m 8601.69916864 m
#  34%|███▎      | 423/1261 [02:53<05:31,  2.53it/s]
# 40612.1023019 m 5069.33151472 m
#  34%|███▎      | 424/1261 [02:54<05:31,  2.52it/s]
# 15732.6805052 m 4586.18326252 m
#  34%|███▎      | 425/1261 [02:54<05:32,  2.51it/s]
# 16189.4179459 m 1990.66411565 m
#  34%|███▍      | 426/1261 [02:55<05:30,  2.52it/s]
# 9951.37658874 m 1375.34013701 m
#  34%|███▍      | 427/1261 [02:55<05:28,  2.54it/s]
# 78211.328469 m 17431.3942814 m
#  34%|███▍      | 428/1261 [02:55<05:27,  2.55it/s]
# 18299.3414624 m 4984.67973084 m
#  34%|███▍      | 429/1261 [02:56<05:28,  2.53it/s]
# 165590.518984 m 4048.27708926 m
#  34%|███▍      | 430/1261 [02:56<05:30,  2.51it/s]
# 260355.818352 m 4922.61741206 m
#  34%|███▍      | 431/1261 [02:57<05:27,  2.53it/s]
# 80211.0696716 m 2252.19967645 m
#  34%|███▍      | 432/1261 [02:57<05:33,  2.49it/s]
# 29264.4480078 m 7428.75761293 m
#  34%|███▍      | 433/1261 [02:57<05:27,  2.53it/s]
# 62595.8264018 m 6904.63957425 m
#  34%|███▍      | 434/1261 [02:58<05:34,  2.48it/s]
# 2087814.44311 m 10174.2379071 m
#  34%|███▍      | 435/1261 [02:58<05:31,  2.49it/s]
# 58418.9341686 m 6135.52346025 m
#  35%|███▍      | 436/1261 [02:59<05:26,  2.53it/s]
# 11555.1673739 m 5043.61833511 m
#  35%|███▍      | 437/1261 [02:59<05:22,  2.55it/s]
# 10324.6119156 m 22442.9054233 m
#  35%|███▍      | 438/1261 [02:59<05:26,  2.52it/s]
# 43673.1805087 m 2887.53464961 m
#  35%|███▍      | 439/1261 [03:00<05:22,  2.55it/s]
# 39774.07829 m 151127.099402 m
#  35%|███▍      | 440/1261 [03:00<05:23,  2.53it/s]
# 165386.390766 m 5376.06066928 m
#  35%|███▍      | 441/1261 [03:01<05:26,  2.51it/s]
# 9171.42589359 m 5136.02562501 m
#  35%|███▌      | 442/1261 [03:01<05:27,  2.50it/s]
# 14166.5191041 m 2027.9604932 m
#  35%|███▌      | 443/1261 [03:01<05:23,  2.53it/s]
# 5374.61540912 m 2681.359393 m
#  35%|███▌      | 444/1261 [03:02<05:21,  2.54it/s]
# 9164.92851291 m 3620.8364992 m
#  35%|███▌      | 445/1261 [03:02<05:24,  2.51it/s]
# 6262.45290074 m 6713.6124807 m
#  35%|███▌      | 446/1261 [03:03<05:21,  2.54it/s]
# 7351.50068978 m 25675.5477577 m
#  35%|███▌      | 447/1261 [03:03<05:20,  2.54it/s]
# 7498.32996766 m 10000.2245638 m
#  36%|███▌      | 448/1261 [03:03<05:22,  2.52it/s]
# 4818.47947719 m 8580.23661118 m
#  36%|███▌      | 449/1261 [03:04<05:18,  2.55it/s]
# 4656.82032101 m 1396.84842776 m
#  36%|███▌      | 450/1261 [03:04<05:17,  2.55it/s]
# 4508.90426276 m 1834.33699676 m
#  36%|███▌      | 451/1261 [03:04<05:18,  2.54it/s]
# 5575.66020347 m 33905.7074135 m
#  36%|███▌      | 452/1261 [03:05<05:20,  2.53it/s]
# 7950.05309343 m 12337.631885 m
#  36%|███▌      | 453/1261 [03:05<05:18,  2.54it/s]
# 19239.2536173 m 5140.71852831 m
#  36%|███▌      | 454/1261 [03:06<05:20,  2.52it/s]
# 15937.8730514 m 3520.71202697 m
#  36%|███▌      | 455/1261 [03:06<05:16,  2.54it/s]
# 10345.0011044 m 3296.19283954 m
#  36%|███▌      | 456/1261 [03:06<05:22,  2.50it/s]
# 14980.8688146 m 5081.45098883 m
#  36%|███▌      | 457/1261 [03:07<05:20,  2.50it/s]
# 8323.12717149 m 7746.08385027 m
#  36%|███▋      | 458/1261 [03:07<05:20,  2.51it/s]
# 13291.1481415 m 28458.9367154 m
#  36%|███▋      | 459/1261 [03:08<05:20,  2.50it/s]
# 17207.8686023 m 5966.96096566 m
#  36%|███▋      | 460/1261 [03:08<05:20,  2.50it/s]
# 11097.3341322 m 10808.5447978 m
#  37%|███▋      | 461/1261 [03:08<05:21,  2.49it/s]
# 8856.6398524 m 17464.5661331 m
#  37%|███▋      | 462/1261 [03:09<05:26,  2.45it/s]
# 9081.70697361 m 2287.13686394 m
#  37%|███▋      | 463/1261 [03:09<05:21,  2.48it/s]
# 12566.3552948 m 72270.6041464 m
#  37%|███▋      | 464/1261 [03:10<05:20,  2.48it/s]
# 24110.7916333 m 5980.55384576 m
#  37%|███▋      | 465/1261 [03:10<05:15,  2.52it/s]
# 16643.0115212 m 4935.41058604 m
#  37%|███▋      | 466/1261 [03:10<05:17,  2.50it/s]
# 35926.8286597 m 3344.60376799 m
#  37%|███▋      | 467/1261 [03:11<05:15,  2.51it/s]
# 35214.693147 m 7153.80521734 m
#  37%|███▋      | 468/1261 [03:11<05:12,  2.54it/s]
# 15893.5188576 m 9993.82764916 m
#  37%|███▋      | 469/1261 [03:12<05:11,  2.54it/s]
# 46726.76886 m 107161.837622 m
#  37%|███▋      | 470/1261 [03:12<05:12,  2.53it/s]
# 20003.0907875 m 8301.31334985 m
#  37%|███▋      | 471/1261 [03:12<05:08,  2.56it/s]
# 8997.49268107 m 3979.59714481 m
#  37%|███▋      | 472/1261 [03:13<05:11,  2.53it/s]
# 6032.06284581 m 3871.10008483 m
#  38%|███▊      | 473/1261 [03:13<05:06,  2.57it/s]
# 3413.2460439 m 9839.18073749 m
#  38%|███▊      | 474/1261 [03:14<05:12,  2.52it/s]
# 6397.51145928 m 14562.3004361 m
#  38%|███▊      | 475/1261 [03:14<05:21,  2.44it/s]
# 8053.20171757 m 4307.23231332 m
#  38%|███▊      | 476/1261 [03:14<05:21,  2.44it/s]
# 8869.90268843 m 5871.11715743 m
#  38%|███▊      | 477/1261 [03:15<05:15,  2.49it/s]
# 14508.2418634 m 4278.92534784 m
#  38%|███▊      | 478/1261 [03:15<05:10,  2.52it/s]
# 27526.0173799 m 6824.30649598 m
#  38%|███▊      | 479/1261 [03:16<05:08,  2.54it/s]
# 37087.5748737 m 2978.01050422 m
#  38%|███▊      | 480/1261 [03:16<05:09,  2.52it/s]
# 12648.4417246 m 6572.66126984 m
#  38%|███▊      | 481/1261 [03:16<05:12,  2.50it/s]
# 10604.2148622 m 32857.4228827 m
#  38%|███▊      | 482/1261 [03:17<05:15,  2.47it/s]
# 7072.94705926 m 55321.4286322 m
#  38%|███▊      | 483/1261 [03:17<05:18,  2.44it/s]
# 7594.66828002 m 8832.26569829 m
#  38%|███▊      | 484/1261 [03:18<05:15,  2.47it/s]
# 7376.52639332 m 11183.8282905 m
#  38%|███▊      | 485/1261 [03:18<05:10,  2.50it/s]
# 5352.57319314 m 2969.3453997 m
#  39%|███▊      | 486/1261 [03:18<05:07,  2.52it/s]
# 4311.99481478 m 3057.28957355 m
#  39%|███▊      | 487/1261 [03:19<05:06,  2.53it/s]
# 6706.74570028 m 7871.40319022 m
#  39%|███▊      | 488/1261 [03:19<05:08,  2.51it/s]
# 9439.57746658 m 4755.56753079 m
#  39%|███▉      | 489/1261 [03:20<05:08,  2.50it/s]
# 11972.9764175 m 4103.45084571 m
#  39%|███▉      | 490/1261 [03:20<05:07,  2.50it/s]
# 18413.7675886 m 5504.84955919 m
#  39%|███▉      | 491/1261 [03:20<05:07,  2.50it/s]
# 13206.198347 m 17445.4071037 m
#  39%|███▉      | 492/1261 [03:21<05:05,  2.52it/s]
# 59738.7015126 m 119710.890714 m
#  39%|███▉      | 493/1261 [03:21<05:02,  2.54it/s]
# 31113.8847743 m 33273.2773415 m
#  39%|███▉      | 494/1261 [03:22<05:02,  2.54it/s]
# 13958.4103621 m 12475.9238644 m
#  39%|███▉      | 495/1261 [03:22<05:04,  2.52it/s]
# 7118.21003165 m 4791.95513886 m
#  39%|███▉      | 496/1261 [03:22<05:04,  2.52it/s]
# 9452.43086573 m 10942.6919991 m
#  39%|███▉      | 497/1261 [03:23<05:04,  2.51it/s]
# 10312.5444712 m 2741.72839604 m
#  39%|███▉      | 498/1261 [03:23<05:06,  2.49it/s]
# 10508.9510882 m 4133.4993987 m
#  40%|███▉      | 499/1261 [03:24<05:08,  2.47it/s]
# 9331.99406237 m 22819.2919812 m
#  40%|███▉      | 500/1261 [03:24<05:11,  2.45it/s]
# 23005.8867704 m 5304.95448406 m
#  40%|███▉      | 501/1261 [03:24<05:06,  2.48it/s]
# 21674.3294632 m 2516.36760817 m
#  40%|███▉      | 502/1261 [03:25<05:05,  2.48it/s]
# 14073.9442474 m 2638.3380222 m
#  40%|███▉      | 503/1261 [03:25<05:03,  2.50it/s]
# 11653.8048672 m 1802.14769627 m
#  40%|███▉      | 504/1261 [03:26<05:03,  2.49it/s]
# 8482.58126682 m 4426.14830465 m
#  40%|████      | 505/1261 [03:26<05:04,  2.49it/s]
# 9896.35231679 m 3632.98977075 m
#  40%|████      | 506/1261 [03:26<05:02,  2.50it/s]
# 12829.6046678 m 30335.1717198 m
#  40%|████      | 507/1261 [03:27<05:00,  2.51it/s]
# 46545.66033 m 7446.77793483 m
#  40%|████      | 508/1261 [03:27<05:02,  2.49it/s]
# 240579.538897 m 3967.50523965 m
#  40%|████      | 509/1261 [03:28<05:01,  2.49it/s]
# 116593.435953 m 1946.52755261 m
#  40%|████      | 510/1261 [03:28<05:01,  2.49it/s]
# 14305.5713199 m 7724.12613559 m
#  41%|████      | 511/1261 [03:28<04:57,  2.52it/s]
# 153086.450445 m 11936.9061626 m
#  41%|████      | 512/1261 [03:29<04:59,  2.50it/s]
# 33447.8458233 m 15795.6234372 m
#  41%|████      | 513/1261 [03:29<04:57,  2.51it/s]
# 27962.4282262 m 10979.2641909 m
#  41%|████      | 514/1261 [03:30<04:54,  2.54it/s]
# 1374255.06148 m 2779.925137 m
#  41%|████      | 515/1261 [03:30<04:50,  2.57it/s]
# 32923.8088569 m 3485.72851922 m
#  41%|████      | 516/1261 [03:30<04:51,  2.56it/s]
# 142894.623582 m 3157.15015165 m
#  41%|████      | 517/1261 [03:31<04:52,  2.55it/s]
# 66206.1883115 m 5729.56255306 m
#  41%|████      | 518/1261 [03:31<04:52,  2.54it/s]
# 65147.4747844 m 8364.04523246 m
#  41%|████      | 519/1261 [03:32<04:54,  2.52it/s]
# 24312.3770286 m 32721.2423278 m
#  41%|████      | 520/1261 [03:32<04:52,  2.53it/s]
# 146844.865629 m 76217.8119175 m
#  41%|████▏     | 521/1261 [03:32<04:48,  2.57it/s]
# 24710.8847576 m 6322.2844647 m
#  41%|████▏     | 522/1261 [03:33<04:49,  2.55it/s]
# 23083.4560186 m 4370.8132528 m
#  41%|████▏     | 523/1261 [03:33<04:45,  2.58it/s]
# 3733.27051149 m 9722.91998962 m
#  42%|████▏     | 524/1261 [03:34<04:43,  2.60it/s]
# 14765.0093468 m 3430.75303105 m
#  42%|████▏     | 525/1261 [03:34<04:46,  2.57it/s]
# 11399.1470275 m 4919.23357751 m
#  42%|████▏     | 526/1261 [03:34<04:47,  2.56it/s]
# 4838.62629498 m 54634.366773 m
#  42%|████▏     | 527/1261 [03:35<04:46,  2.56it/s]
# 22174.8686712 m 2229.34340826 m
#  42%|████▏     | 528/1261 [03:35<04:45,  2.56it/s]
# 36386.12286 m 3582.91019182 m
#  42%|████▏     | 529/1261 [03:35<04:44,  2.57it/s]
# 5750.48702354 m 6450.19024433 m
#  42%|████▏     | 530/1261 [03:36<04:47,  2.55it/s]
# 3500.5438157 m 8249.81727368 m
#  42%|████▏     | 531/1261 [03:36<04:47,  2.54it/s]
# 5779.25127308 m 8165.81870006 m
#  42%|████▏     | 532/1261 [03:37<04:54,  2.48it/s]
# 58585.1306363 m 3890.95313261 m
#  42%|████▏     | 533/1261 [03:37<05:01,  2.41it/s]
# 4872.57205434 m 1215.05889496 m
#  42%|████▏     | 534/1261 [03:38<05:12,  2.33it/s]
# 5688.3940061 m 1982.06501718 m
#  42%|████▏     | 535/1261 [03:38<05:16,  2.30it/s]
# 16790.6186691 m 2487.77566577 m
#  43%|████▎     | 536/1261 [03:38<05:07,  2.36it/s]
# 23800.1349396 m 5427.50264512 m
#  43%|████▎     | 537/1261 [03:39<04:58,  2.43it/s]
# 5356.52262877 m 32494.8133575 m
#  43%|████▎     | 538/1261 [03:39<04:53,  2.46it/s]
# 2281.88188927 m 2724.53554052 m
#  43%|████▎     | 539/1261 [03:40<04:53,  2.46it/s]
# 6298.04433176 m 1522.95717581 m
#  43%|████▎     | 540/1261 [03:40<04:54,  2.45it/s]
# 6125.84818789 m 610.168245368 m
#  43%|████▎     | 541/1261 [03:40<04:51,  2.47it/s]
# 4146.74823353 m 671.444430918 m
#  43%|████▎     | 542/1261 [03:41<04:57,  2.41it/s]
# 7624.81832244 m 1702.79712311 m
#  43%|████▎     | 543/1261 [03:41<05:05,  2.35it/s]
# 4507.97218262 m 4869.72679846 m
#  43%|████▎     | 544/1261 [03:42<05:11,  2.30it/s]
# 2609.17825829 m 1219.89014252 m
#  43%|████▎     | 545/1261 [03:42<05:01,  2.37it/s]
# 1471.92461686 m 495.518819763 m
#  43%|████▎     | 546/1261 [03:43<05:07,  2.33it/s]
# 1056.45852734 m 415.092088036 m
#  43%|████▎     | 547/1261 [03:43<05:09,  2.31it/s]
# 1143.04766626 m 1088.51926898 m
#  43%|████▎     | 548/1261 [03:44<05:08,  2.31it/s]
# 1948.39065726 m 6429.03837962 m
#  44%|████▎     | 549/1261 [03:44<05:18,  2.24it/s]
# 12058.0389765 m 4839.49165288 m
#  44%|████▎     | 550/1261 [03:44<05:16,  2.25it/s]
# 6692.80777717 m 1958.1733472 m
#  44%|████▎     | 551/1261 [03:45<05:20,  2.22it/s]
# 2128.52294887 m 58316.9579566 m
#  44%|████▍     | 552/1261 [03:45<05:20,  2.21it/s]
# 1363.02459111 m 10556.6616839 m
#  44%|████▍     | 553/1261 [03:46<05:25,  2.18it/s]
# 955.054809062 m 3346.61149671 m
#  44%|████▍     | 554/1261 [03:46<05:28,  2.15it/s]
# 770.083283554 m 1376.80861413 m
#  44%|████▍     | 555/1261 [03:47<05:31,  2.13it/s]
# 746.630081521 m 859.109014121 m
#  44%|████▍     | 556/1261 [03:47<05:30,  2.13it/s]
# 921.423040764 m 880.503848195 m
#  44%|████▍     | 557/1261 [03:48<05:34,  2.11it/s]
# 962.51497166 m 1105.36775473 m
#  44%|████▍     | 558/1261 [03:48<05:33,  2.11it/s]
# 2080.65546458 m 2575.71810178 m
#  44%|████▍     | 559/1261 [03:49<05:35,  2.09it/s]
# 2102.77150286 m 3385.2780034 m
#  44%|████▍     | 560/1261 [03:49<05:31,  2.12it/s]
# 1833.02597485 m 3240.47802756 m
#  44%|████▍     | 561/1261 [03:50<05:28,  2.13it/s]
# 2298.34078159 m 5347.51209672 m
#  45%|████▍     | 562/1261 [03:50<05:25,  2.15it/s]
# 1491.41747497 m 1635.13070856 m
#  45%|████▍     | 563/1261 [03:51<05:22,  2.16it/s]
# 5120.04756614 m 1644.57680525 m
#  45%|████▍     | 564/1261 [03:51<05:23,  2.16it/s]
# 1572.40786019 m 712.120668556 m
#  45%|████▍     | 565/1261 [03:51<05:18,  2.18it/s]
# 2385.26203718 m 2024.3293985 m
#  45%|████▍     | 566/1261 [03:52<05:17,  2.19it/s]
# 12099.2869964 m 1144.38698681 m
#  45%|████▍     | 567/1261 [03:52<05:15,  2.20it/s]
# 7324.36503389 m 1690.99107214 m
#  45%|████▌     | 568/1261 [03:53<05:12,  2.22it/s]
# 31117.6021406 m 957.106194687 m
#  45%|████▌     | 569/1261 [03:53<05:08,  2.24it/s]
# 10161.113466 m 787.502834747 m
#  45%|████▌     | 570/1261 [03:54<05:04,  2.27it/s]
# 4142.78838346 m 518.818487738 m
#  45%|████▌     | 571/1261 [03:54<04:59,  2.30it/s]
# 48315.4726699 m 2899.02249374 m
#  45%|████▌     | 572/1261 [03:54<04:54,  2.34it/s]
# 18319.415672 m 2859.85726179 m
#  45%|████▌     | 573/1261 [03:55<04:59,  2.30it/s]
# 11749.5246265 m 1284.13696224 m
#  46%|████▌     | 574/1261 [03:55<04:55,  2.33it/s]
# 12592.4501518 m 14666.0813814 m
#  46%|████▌     | 575/1261 [03:56<04:57,  2.30it/s]
# 10973.5938682 m 6396.22350912 m
#  46%|████▌     | 576/1261 [03:56<04:57,  2.30it/s]
# 4094.25700948 m 65609.4510223 m
#  46%|████▌     | 577/1261 [03:57<04:58,  2.29it/s]
# 1654.29900916 m 2711.94131593 m
#  46%|████▌     | 578/1261 [03:57<05:00,  2.28it/s]
# 915.410492545 m 16829.0736904 m
#  46%|████▌     | 579/1261 [03:58<04:52,  2.33it/s]
# 1177.59308999 m 13581.1422143 m
# ...
#  85%|████████▌ | 1072/1261 [07:45<01:19,  2.39it/s]
# 4001.84935695 m 1160.7343624 m
#  85%|████████▌ | 1073/1261 [07:45<01:17,  2.41it/s]
# 4399.95369085 m 3712.59757149 m
#  85%|████████▌ | 1074/1261 [07:46<01:16,  2.45it/s]
# 4765.81600632 m 1748.79177908 m
#  85%|████████▌ | 1075/1261 [07:46<01:16,  2.42it/s]
# 7305.43819689 m 1421.46941793 m
#  85%|████████▌ | 1076/1261 [07:47<01:17,  2.39it/s]
# 7637.32989823 m 960.230755228 m
#  85%|████████▌ | 1077/1261 [07:47<01:21,  2.26it/s]
# 7604.58507866 m 2669.90219893 m
#  85%|████████▌ | 1078/1261 [07:47<01:20,  2.26it/s]
# 4395.35827172 m 59105.3022996 m
#  86%|████████▌ | 1079/1261 [07:48<01:20,  2.26it/s]
# 5636.48774278 m 12050.6051537 m
#  86%|████████▌ | 1080/1261 [07:48<01:19,  2.28it/s]
# 5490.71864567 m 8025.40579539 m
#  86%|████████▌ | 1081/1261 [07:49<01:19,  2.27it/s]
# 4085.75107157 m 74849.9073041 m
#  86%|████████▌ | 1082/1261 [07:49<01:16,  2.32it/s]
# 4346.08533303 m 5043.36382831 m
#  86%|████████▌ | 1083/1261 [07:50<01:15,  2.36it/s]
# 3669.24743414 m 2423.01780044 m
#  86%|████████▌ | 1084/1261 [07:50<01:14,  2.37it/s]
# 2758.5852518 m 1552.26334945 m
#  86%|████████▌ | 1085/1261 [07:50<01:13,  2.39it/s]
# 2811.33192687 m 12534.3718335 m
#  86%|████████▌ | 1086/1261 [07:51<01:14,  2.36it/s]
# 3035.98572895 m 44897.9727498 m
#  86%|████████▌ | 1087/1261 [07:51<01:13,  2.38it/s]
# 3046.16210467 m 3123.40113766 m
#  86%|████████▋ | 1088/1261 [07:52<01:11,  2.40it/s]
# 3191.74638334 m 2905.69996815 m
#  86%|████████▋ | 1089/1261 [07:52<01:11,  2.42it/s]
# 3214.04503947 m 3183.64466618 m
#  86%|████████▋ | 1090/1261 [07:52<01:09,  2.45it/s]
# 2543.35697348 m 8980.45465356 m
#  87%|████████▋ | 1091/1261 [07:53<01:09,  2.45it/s]
# 2357.00494494 m 10250.2830938 m
#  87%|████████▋ | 1092/1261 [07:53<01:08,  2.46it/s]
# 3486.03439616 m 3801.48152907 m
#  87%|████████▋ | 1093/1261 [07:54<01:07,  2.48it/s]
# 3491.18501153 m 1923.23785796 m
#  87%|████████▋ | 1094/1261 [07:54<01:06,  2.49it/s]
# 4372.87244398 m 1968.65871046 m
#  87%|████████▋ | 1095/1261 [07:54<01:05,  2.52it/s]
# 2680.44014896 m 1318.65118048 m
#  87%|████████▋ | 1096/1261 [07:55<01:05,  2.53it/s]
# 2685.58915148 m 4658.41556504 m
#  87%|████████▋ | 1097/1261 [07:55<01:06,  2.48it/s]
# 2786.7777854 m 2003.54462545 m
#  87%|████████▋ | 1098/1261 [07:56<01:05,  2.47it/s]
# 2148.94555987 m 2203.432629 m
#  87%|████████▋ | 1099/1261 [07:56<01:06,  2.43it/s]
# 2722.96219436 m 913.245638825 m
#  87%|████████▋ | 1100/1261 [07:57<01:07,  2.39it/s]
# 4222.50026197 m 10984.4554714 m
#  87%|████████▋ | 1101/1261 [07:57<01:08,  2.33it/s]
# 3530.29378791 m 11390.8235231 m
#  87%|████████▋ | 1102/1261 [07:57<01:09,  2.28it/s]
# 6064.15509931 m 11058.4935289 m
#  87%|████████▋ | 1103/1261 [07:58<01:09,  2.28it/s]
# 12941.0440302 m 9712.21941233 m
#  88%|████████▊ | 1104/1261 [07:58<01:09,  2.25it/s]
# 19624.0556236 m 27568.7190763 m
#  88%|████████▊ | 1105/1261 [07:59<01:11,  2.17it/s]
# 19438.9559566 m 44584.1751371 m
#  88%|████████▊ | 1106/1261 [07:59<01:13,  2.12it/s]
# 128652.845042 m 3535.20515993 m
#  88%|████████▊ | 1107/1261 [08:00<01:10,  2.18it/s]
# 8568.33437088 m 4656.10732571 m
#  88%|████████▊ | 1108/1261 [08:00<01:08,  2.25it/s]
# 5524.85015719 m 3243.02035379 m
#  88%|████████▊ | 1109/1261 [08:01<01:06,  2.30it/s]
# 3438.04918576 m 9931.8782883 m
#  88%|████████▊ | 1110/1261 [08:01<01:05,  2.32it/s]
# 3607.47841936 m 6600.13210935 m
#  88%|████████▊ | 1111/1261 [08:01<01:03,  2.36it/s]
# 3243.88839996 m 2329.09400191 m
#  88%|████████▊ | 1112/1261 [08:02<01:03,  2.35it/s]
# 2714.92804353 m 7348.23411374 m
#  88%|████████▊ | 1113/1261 [08:02<01:02,  2.35it/s]
# 2438.53010968 m 4799.89254553 m
#  88%|████████▊ | 1114/1261 [08:03<01:02,  2.34it/s]
# 2376.22497844 m 4359.75923387 m
#  88%|████████▊ | 1115/1261 [08:03<01:01,  2.37it/s]
# 2246.51911185 m 2784.47860211 m
#  89%|████████▊ | 1116/1261 [08:04<01:05,  2.22it/s]
# 2883.69491324 m 1279.44581696 m
#  89%|████████▊ | 1117/1261 [08:04<01:05,  2.19it/s]
# 2646.29333405 m 1538.75962603 m
#  89%|████████▊ | 1118/1261 [08:05<01:03,  2.25it/s]
# 2489.43771074 m 1630.86807965 m
#  89%|████████▊ | 1119/1261 [08:05<01:01,  2.31it/s]
# 3939.06340642 m 2639.99786772 m
#  89%|████████▉ | 1120/1261 [08:05<00:59,  2.37it/s]
# 4542.30662535 m 1686.06444381 m
#  89%|████████▉ | 1121/1261 [08:06<01:00,  2.30it/s]
# 4382.86243244 m 1532.00417482 m
#  89%|████████▉ | 1122/1261 [08:06<01:01,  2.25it/s]
# 5168.28301698 m 1062.06401317 m
#  89%|████████▉ | 1123/1261 [08:07<01:07,  2.04it/s]
# 6776.08756824 m 1399.55902709 m
#  89%|████████▉ | 1124/1261 [08:07<01:08,  2.01it/s]
# 7639.25885101 m 46920.1568868 m
#  89%|████████▉ | 1125/1261 [08:08<01:04,  2.09it/s]
# 5431.95293972 m 18329.3826721 m
#  89%|████████▉ | 1126/1261 [08:08<01:02,  2.16it/s]
# 4568.75306995 m 7004.81900055 m
#  89%|████████▉ | 1127/1261 [08:09<01:00,  2.21it/s]
# 3940.944922 m 3442.88181817 m
#  89%|████████▉ | 1128/1261 [08:09<00:59,  2.22it/s]
# 4104.88648918 m 3388.39551146 m
#  90%|████████▉ | 1129/1261 [08:10<00:58,  2.25it/s]
# 4905.40578597 m 1142.05295633 m
#  90%|████████▉ | 1130/1261 [08:10<00:59,  2.20it/s]
# 2402.07729221 m 3197.22380696 m
#  90%|████████▉ | 1131/1261 [08:10<00:58,  2.24it/s]
# 2404.66208715 m 29730.2644519 m
#  90%|████████▉ | 1132/1261 [08:11<00:57,  2.23it/s]
# 2211.98455006 m 1747.81301493 m
#  90%|████████▉ | 1133/1261 [08:11<00:55,  2.31it/s]
# 1882.6666035 m 3082.16091036 m
#  90%|████████▉ | 1134/1261 [08:12<00:54,  2.34it/s]
# 1999.40544687 m 1123.58324419 m
#  90%|█████████ | 1135/1261 [08:12<00:54,  2.29it/s]
# 2248.82111061 m 60308.0868991 m
#  90%|█████████ | 1136/1261 [08:13<00:55,  2.26it/s]
# 1819.78397023 m 5880.58926859 m
#  90%|█████████ | 1137/1261 [08:13<00:55,  2.22it/s]
# 1976.34830803 m 5350.46556943 m
#  90%|█████████ | 1138/1261 [08:14<00:54,  2.27it/s]
# 2832.04291658 m 2782.97439326 m
#  90%|█████████ | 1139/1261 [08:14<00:53,  2.28it/s]
# 3235.0755872 m 2458.95995005 m
#  90%|█████████ | 1140/1261 [08:14<00:51,  2.34it/s]
# 2874.12097708 m 2332.33863479 m
#  90%|█████████ | 1141/1261 [08:15<00:50,  2.40it/s]
# 3896.87500838 m 10726.0782983 m
#  91%|█████████ | 1142/1261 [08:15<00:49,  2.41it/s]
# 3269.76086719 m 30095.1567521 m
#  91%|█████████ | 1143/1261 [08:16<00:48,  2.43it/s]
# 4315.34637791 m 1737.94683514 m
#  91%|█████████ | 1144/1261 [08:16<00:48,  2.43it/s]
# 4058.89269603 m 1863.43424028 m
#  91%|█████████ | 1145/1261 [08:16<00:47,  2.43it/s]
# 5665.25234407 m 2731.70230509 m
#  91%|█████████ | 1146/1261 [08:17<00:48,  2.36it/s]
# 4471.765749 m 2754.19437356 m
#  91%|█████████ | 1147/1261 [08:17<00:49,  2.30it/s]
# 2764.42210006 m 5491.66607914 m
#  91%|█████████ | 1148/1261 [08:18<00:51,  2.21it/s]
# 2858.73649398 m 5531.97328389 m
#  91%|█████████ | 1149/1261 [08:18<00:51,  2.18it/s]
# 3868.12631116 m 3219.67341259 m
#  91%|█████████ | 1150/1261 [08:19<00:52,  2.12it/s]
# 3711.54832611 m 2059.81758107 m
#  91%|█████████▏| 1151/1261 [08:19<00:51,  2.12it/s]
# 4107.68600588 m 2234.95116699 m
#  91%|█████████▏| 1152/1261 [08:20<00:51,  2.11it/s]
# 3143.39746001 m 1113.14774338 m
#  91%|█████████▏| 1153/1261 [08:20<00:50,  2.12it/s]
# 4486.19321387 m 29019.7424868 m
#  92%|█████████▏| 1154/1261 [08:21<00:50,  2.13it/s]
# 19182.3567597 m 3435.95198603 m
#  92%|█████████▏| 1155/1261 [08:21<00:49,  2.15it/s]
# 4842.57904944 m 2178.92474346 m
#  92%|█████████▏| 1156/1261 [08:22<00:48,  2.14it/s]
# 3180.90287584 m 1526.8295342 m
#  92%|█████████▏| 1157/1261 [08:22<00:48,  2.13it/s]
# 2677.25236644 m 3760.51158106 m
#  92%|█████████▏| 1158/1261 [08:22<00:47,  2.16it/s]
# 2846.83186526 m 46461.0776623 m
#  92%|█████████▏| 1159/1261 [08:23<00:46,  2.20it/s]
# 1824.1390023 m 13453.2376742 m
#  92%|█████████▏| 1160/1261 [08:23<00:44,  2.26it/s]
# 2076.05278456 m 3328.36580887 m
#  92%|█████████▏| 1161/1261 [08:24<00:44,  2.27it/s]
# 2135.52504595 m 2177.90470878 m
#  92%|█████████▏| 1162/1261 [08:24<00:43,  2.26it/s]
# 2526.63708812 m 2200.46395341 m
#  92%|█████████▏| 1163/1261 [08:25<00:44,  2.21it/s]
# 2537.27613066 m 1161.90804691 m
#  92%|█████████▏| 1164/1261 [08:25<00:44,  2.17it/s]
# 2986.18346868 m 12912.9132272 m
#  92%|█████████▏| 1165/1261 [08:26<00:45,  2.12it/s]
# 2781.14663573 m 5060.56829727 m
#  92%|█████████▏| 1166/1261 [08:26<00:44,  2.12it/s]
# 2098.38161069 m 2957.26696336 m
#  93%|█████████▎| 1167/1261 [08:27<00:45,  2.07it/s]
# 1838.09293845 m 1574.84276901 m
#  93%|█████████▎| 1168/1261 [08:27<00:46,  2.02it/s]
# 1785.81335658 m 1212.60900996 m
#  93%|█████████▎| 1169/1261 [08:28<00:45,  2.00it/s]
# 1710.59974061 m 28257.4102977 m
#  93%|█████████▎| 1170/1261 [08:28<00:44,  2.04it/s]
# 1672.41280907 m 3852.87510047 m
#  93%|█████████▎| 1171/1261 [08:29<00:43,  2.07it/s]
# 2185.96118877 m 3148.04874989 m
#  93%|█████████▎| 1172/1261 [08:29<00:42,  2.08it/s]
# 2803.00407141 m 1843.42434677 m
#  93%|█████████▎| 1173/1261 [08:30<00:42,  2.06it/s]
# 3419.40409846 m 1905.38039776 m
#  93%|█████████▎| 1174/1261 [08:30<00:41,  2.07it/s]
# 4442.14760086 m 1378.15016523 m
#  93%|█████████▎| 1175/1261 [08:31<00:41,  2.09it/s]
# 3314.28422741 m 1355.44089438 m
#  93%|█████████▎| 1176/1261 [08:31<00:38,  2.19it/s]
# 4192.89142653 m 3388.90125722 m
#  93%|█████████▎| 1177/1261 [08:31<00:37,  2.24it/s]
# 3745.81228448 m 2164.95940744 m
#  93%|█████████▎| 1178/1261 [08:32<00:36,  2.29it/s]
# 5008.36864857 m 2104.48183929 m
#  93%|█████████▎| 1179/1261 [08:32<00:35,  2.34it/s]
# 5750.15829022 m 2233.14203329 m
#  94%|█████████▎| 1180/1261 [08:33<00:34,  2.35it/s]
# 7908.37902746 m 2661.25218298 m
#  94%|█████████▎| 1181/1261 [08:33<00:33,  2.36it/s]
# 5663.33322173 m 15863.1367123 m
#  94%|█████████▎| 1182/1261 [08:33<00:32,  2.41it/s]
# 2901.9887195 m 13693.4628035 m
#  94%|█████████▍| 1183/1261 [08:34<00:33,  2.30it/s]
# 4471.41231366 m 105674.491687 m
#  94%|█████████▍| 1184/1261 [08:34<00:33,  2.28it/s]
# 4203.90298647 m 11359.1283684 m
#  94%|█████████▍| 1185/1261 [08:35<00:32,  2.33it/s]
# 6651.37342032 m 3516.7120326 m
#  94%|█████████▍| 1186/1261 [08:35<00:31,  2.37it/s]
# 5261.44294713 m 2209.46197248 m
#  94%|█████████▍| 1187/1261 [08:36<00:30,  2.40it/s]
# 2857.03736015 m 5060.0618443 m
#  94%|█████████▍| 1188/1261 [08:36<00:30,  2.42it/s]
# 3846.45964212 m 3142.58390122 m
#  94%|█████████▍| 1189/1261 [08:36<00:30,  2.40it/s]
# 4369.09442591 m 2673.97312713 m
#  94%|█████████▍| 1190/1261 [08:37<00:29,  2.39it/s]
# 5967.55812995 m 1748.8244928 m
#  94%|█████████▍| 1191/1261 [08:37<00:29,  2.41it/s]
# 4577.64724096 m 67996.4793507 m
#  95%|█████████▍| 1192/1261 [08:38<00:28,  2.43it/s]
# 3156.1537595 m 3128.61734882 m
#  95%|█████████▍| 1193/1261 [08:38<00:28,  2.39it/s]
# 3685.67212371 m 2557.20644168 m
#  95%|█████████▍| 1194/1261 [08:39<00:28,  2.33it/s]
# 2590.38052803 m 2190.86763462 m
#  95%|█████████▍| 1195/1261 [08:39<00:29,  2.21it/s]
# 2638.79308348 m 1803.01028604 m
#  95%|█████████▍| 1196/1261 [08:39<00:30,  2.16it/s]
# 2504.95195504 m 1855.43412766 m
#  95%|█████████▍| 1197/1261 [08:40<00:29,  2.20it/s]
# 2568.48646907 m 2118.40581054 m
#  95%|█████████▌| 1198/1261 [08:40<00:28,  2.22it/s]
# 2108.8512255 m 12019.8380031 m
#  95%|█████████▌| 1199/1261 [08:41<00:27,  2.23it/s]
# 2040.12524044 m 1892.86860783 m
#  95%|█████████▌| 1200/1261 [08:41<00:26,  2.29it/s]
# 2361.34487325 m 2653.20957565 m
#  95%|█████████▌| 1201/1261 [08:42<00:25,  2.31it/s]
# 2937.49990706 m 48708.7342755 m
#  95%|█████████▌| 1202/1261 [08:42<00:25,  2.33it/s]
# 3016.61728935 m 15469.6505509 m
#  95%|█████████▌| 1203/1261 [08:43<00:25,  2.26it/s]
# 3204.65148833 m 5225.61699805 m
#  95%|█████████▌| 1204/1261 [08:43<00:25,  2.24it/s]
# 2741.42198506 m 13996.2513139 m
#  96%|█████████▌| 1205/1261 [08:43<00:24,  2.27it/s]
# 3796.65184291 m 5273.89198072 m
#  96%|█████████▌| 1206/1261 [08:44<00:24,  2.26it/s]
# 4366.65576159 m 3197.55959124 m
#  96%|█████████▌| 1207/1261 [08:44<00:24,  2.25it/s]
# 4286.5353305 m 1720.36430329 m
#  96%|█████████▌| 1208/1261 [08:45<00:23,  2.26it/s]
# 2588.46258755 m 1428.33379275 m
#  96%|█████████▌| 1209/1261 [08:45<00:23,  2.25it/s]
# 2944.94591561 m 5381.51564717 m
#  96%|█████████▌| 1210/1261 [08:46<00:22,  2.30it/s]
# 2448.56135164 m 3916.09523591 m
#  96%|█████████▌| 1211/1261 [08:46<00:21,  2.38it/s]
# 2099.43450478 m 2223.24841934 m
#  96%|█████████▌| 1212/1261 [08:46<00:20,  2.44it/s]
# 1754.04976445 m 1646.20151566 m
#  96%|█████████▌| 1213/1261 [08:47<00:19,  2.47it/s]
# 1906.66683935 m 2880.11336254 m
#  96%|█████████▋| 1214/1261 [08:47<00:18,  2.48it/s]
# 1771.27840771 m 1738.60399226 m
#  96%|█████████▋| 1215/1261 [08:48<00:18,  2.51it/s]
# 1758.99929847 m 8914.14508604 m
#  96%|█████████▋| 1216/1261 [08:48<00:17,  2.51it/s]
# 1841.27550321 m 55876.3998504 m
#  97%|█████████▋| 1217/1261 [08:48<00:17,  2.44it/s]
# 2494.62407686 m 10359.4598933 m
#  97%|█████████▋| 1218/1261 [08:49<00:17,  2.40it/s]
# 3144.50552053 m 23728.4285865 m
#  97%|█████████▋| 1219/1261 [08:49<00:17,  2.37it/s]
# 3667.7963129 m 16866.417525 m
#  97%|█████████▋| 1220/1261 [08:50<00:18,  2.21it/s]
# 2566.12933728 m 1839.80040473 m
#  97%|█████████▋| 1221/1261 [08:50<00:19,  2.07it/s]
# 3552.02167547 m 2540.5450972 m
#  97%|█████████▋| 1222/1261 [08:51<00:19,  1.98it/s]
# 2384.77536231 m 1157.36447608 m
#  97%|█████████▋| 1223/1261 [08:51<00:19,  1.93it/s]
# 2697.40922822 m 8704.76478666 m
#  97%|█████████▋| 1224/1261 [08:52<00:18,  2.01it/s]
# 2915.99997749 m 365866.833527 m
#  97%|█████████▋| 1225/1261 [08:52<00:17,  2.01it/s]
# 2384.82775639 m 3465.00528448 m
#  97%|█████████▋| 1226/1261 [08:53<00:16,  2.11it/s]
# 1760.54241877 m 1970.06931201 m
#  97%|█████████▋| 1227/1261 [08:53<00:15,  2.23it/s]
# 2152.12266589 m 3834.25189122 m
#  97%|█████████▋| 1228/1261 [08:54<00:14,  2.32it/s]
# 3216.61595035 m 2408.06639937 m
#  97%|█████████▋| 1229/1261 [08:54<00:13,  2.40it/s]
# 3888.02157144 m 1367.86066187 m
#  98%|█████████▊| 1230/1261 [08:54<00:12,  2.46it/s]
# 6786.69305355 m 3935.01334668 m
#  98%|█████████▊| 1231/1261 [08:55<00:12,  2.49it/s]
# 6510.13321255 m 4280.20676017 m
#  98%|█████████▊| 1232/1261 [08:55<00:11,  2.52it/s]
# 3780.7207843 m 1722.00297964 m
#  98%|█████████▊| 1233/1261 [08:56<00:11,  2.49it/s]
# 3907.24160747 m 899.701156654 m
#  98%|█████████▊| 1234/1261 [08:56<00:10,  2.51it/s]
# 2616.07690186 m 1248.74326782 m
#  98%|█████████▊| 1235/1261 [08:56<00:10,  2.55it/s]
# 2617.15936901 m 1708.23030802 m
#  98%|█████████▊| 1236/1261 [08:57<00:09,  2.57it/s]
# 2697.1484448 m 5193.4010439 m
#  98%|█████████▊| 1237/1261 [08:57<00:09,  2.51it/s]
# 2736.16386564 m 12854.1160254 m
#  98%|█████████▊| 1238/1261 [08:58<00:09,  2.50it/s]
# 3352.61145906 m 3144.09710899 m
#  98%|█████████▊| 1239/1261 [08:58<00:08,  2.49it/s]
# 3533.64690378 m 3824.37729278 m
#  98%|█████████▊| 1240/1261 [08:58<00:08,  2.51it/s]
# 9736.11641662 m 1899.3522949 m
#  98%|█████████▊| 1241/1261 [08:59<00:07,  2.52it/s]
# 38231.0163425 m 3064.63448175 m
#  98%|█████████▊| 1242/1261 [08:59<00:07,  2.57it/s]
# 51672.4821235 m 27496.6267782 m
#  99%|█████████▊| 1243/1261 [08:59<00:07,  2.55it/s]
# 17127.1457809 m 8929.01159227 m
#  99%|█████████▊| 1244/1261 [09:00<00:06,  2.51it/s]
# 17948.0152373 m 2473.20266872 m
#  99%|█████████▊| 1245/1261 [09:00<00:06,  2.55it/s]
# 337257.500202 m 5662.73462511 m
#  99%|█████████▉| 1246/1261 [09:01<00:05,  2.56it/s]
# 7346.9825511 m 1861.90012601 m
#  99%|█████████▉| 1247/1261 [09:01<00:05,  2.57it/s]
# 4317.81502729 m 2516.07269585 m
#  99%|█████████▉| 1248/1261 [09:01<00:05,  2.53it/s]
# 4281.35205138 m 4013.75285713 m
#  99%|█████████▉| 1249/1261 [09:02<00:04,  2.53it/s]
# 3753.94234772 m 34682.643832 m
#  99%|█████████▉| 1250/1261 [09:02<00:04,  2.56it/s]
# 6262.17131815 m 10969.0422179 m
#  99%|█████████▉| 1251/1261 [09:03<00:03,  2.57it/s]
# 8846.25671456 m 22060.9746262 m
#  99%|█████████▉| 1252/1261 [09:03<00:03,  2.57it/s]
# 8932.05355124 m 31863.7348726 m
#  99%|█████████▉| 1253/1261 [09:03<00:03,  2.61it/s]
# 13967.8088509 m 3293.98432205 m
#  99%|█████████▉| 1254/1261 [09:04<00:02,  2.53it/s]
# 20371.3804588 m 1748.62198478 m
# 100%|█████████▉| 1255/1261 [09:04<00:02,  2.57it/s]
# 7405.64414769 m 51976.3798182 m
# 100%|█████████▉| 1256/1261 [09:05<00:02,  2.49it/s]
# 5862.65560171 m 73394.7789272 m
# 100%|█████████▉| 1257/1261 [09:05<00:01,  2.51it/s]
# 12832.3338634 m 38616.3991845 m
# 100%|█████████▉| 1258/1261 [09:05<00:01,  2.51it/s]
# 25504.1519603 m 1703.18126486 m
# 100%|█████████▉| 1259/1261 [09:06<00:00,  2.45it/s]
# 130227.964377 m 3219.86434688 m
# 100%|█████████▉| 1260/1261 [09:06<00:00,  2.50it/s]
# 16438.7983201 m 7662.1795204 m
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: advanced_lane_lines.mp4
#
# CPU times: user 8min 6s, sys: 1min 53s, total: 9min 59s
# Wall time: 9min 8s
